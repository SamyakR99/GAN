# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np 
import matplotlib 
import os
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Conv2DTranspose, Flatten, BatchNormalization , ReLU, LeakyReLU, Dropout,Reshape
from keras.optimizers import Adam
import cv2

import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
def discriminator():
	model = Sequential()
	model.add(Conv2D(8, (3,3) , strides= (2,2), padding= 'same',input_shape = (256,256,3)))
	model.add(LeakyReLU(0.2))
	model.add(Dropout(0.3))

#128*128*8
	
	model.add(Conv2D(16, (3,3) , strides= (2,2), padding= 'same'))
	model.add(BatchNormalization( momentum= 0.7))
	model.add(LeakyReLU(0.2))
	#model.add(Dropout(0.3))
#64*64*16

	model.add(Conv2D(32, (3,3) , strides= (2,2), padding= 'same'))
	model.add(BatchNormalization(momentum= 0.7))
	model.add(LeakyReLU(0.2))
	#model.add(Dropout(0.3))
#32*32*32

	model.add(Conv2D(64, (3,3) , strides= (2,2), padding= 'same'))
	model.add(BatchNormalization(momentum= 0.7))
	model.add(LeakyReLU(0.2))
	model.add(Dropout(0.3))
#16*16*64

	model.add(Conv2D(128, (3,3) , strides= (2,2), padding= 'same'))
	model.add(BatchNormalization(momentum= 0.7))
	model.add(LeakyReLU(0.2))
	#model.add(Dropout(0.3))
#8*8*128
	model.add(Conv2D(256, (3,3) , strides= (2,2), padding= 'same'))
	model.add(BatchNormalization(momentum= 0.7))
	model.add(LeakyReLU(0.2))
	model.add(Dropout(0.3))
#4*4*256
	model.add(Flatten())
	model.add(Dense(128))
	model.add(LeakyReLU(0.2))


	model.add(Dense(1,activation ='sigmoid'))
	optimus = Adam(learning_rate= 0.0002 ,beta_1=0.5)
	model.compile(optimizer= optimus, loss = 'binary_crossentropy',metrics=['accuracy'])

	return model

# %%
def generator(latent_dim):
  
	model = Sequential()
	model.add(Dense((4096),input_dim = latent_dim))
	model.add(Reshape((1,1,4096)))

	model.add(Conv2DTranspose(512, (4,4) , strides=(2,2), padding='same'))
	model.add(ReLU())
#2*2*512
	model.add(Conv2DTranspose(256,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	#model.add(Dropout(0.3))
#4*4*256
	model.add(Conv2DTranspose(128,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	#model.add(Dropout(0.3))
#8*8*128
	model.add(Conv2DTranspose(128,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	#model.add(Dropout(0.3))
#16*16*128
	model.add(Conv2DTranspose(128,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	#model.add(Dropout(0.3))
#32*32*128
	model.add(Conv2DTranspose(128,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	#model.add(Dropout(0.3))
#64*64*128	
	model.add(Conv2DTranspose(128,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	model.add(Dropout(0.3))
#128*128*128

	model.add(Conv2DTranspose(128,(4,4),strides= 2, padding = 'same'))
	model.add(BatchNormalization(momentum=0.7))
	model.add(ReLU())
	#model.add(Dropout(0.3))

#256*256*4
	model.add(Conv2D(3,(3,3),activation= 'tanh',padding = 'same'))
	optimus = Adam(learning_rate=0.0002,beta_1=0.5)

	model.compile(optimizer=optimus , loss = 'binary_crossentropy')

	return model

# %%
def gan(g_model,d_model):

	d_model.trainable = False
	model =Sequential()
	model.add(g_model)
	model.add(d_model)
	optimus = Adam(learning_rate=0.0002,beta_1=0.5)
	model.compile(optimizer=optimus,loss='binary_crossentropy')
	return model

# %%
def load_real_data(xsam):
    
    x= np.array(xsam).reshape(-1,256,256,3)
    x = (x-127.5)/127.5
    print(x.shape)
    return x

# %%
def generate_real_samples(dataset , n_samples):

	for i in range (n_samples):
		index = np.random.randint(0 , dataset.shape[0] , n_samples)

		image = dataset[index]
		y = np.ones((n_samples,1))

		return image,y

# %%
def generate_latent_sample(laten_dim,n_samples):
	
	x = np.random.randn(laten_dim*n_samples)
	x = x.reshape(n_samples,laten_dim)

	return x

# %%
def generate_fake_samples(g_model, latent_dim,n_samples):
	
	x = generate_latent_sample(latent_dim,n_samples)
	x = g_model.predict(x)
	y = np.zeros((n_samples,1))

	return x,y

# %%
def save_plot(examples ,epoch , n = 3):
	examples = (examples+1) / 2.0

	for i in range(n*n):
		pyplot.subplot(3,3,1+i)
		pyplot.axis('off')
		pyplot.imshow(examples[i])
	filename = 'generated_plot_e%0.3d.png' % (epoch+1)
	pyplot.savefig(filename)
	pyplot.close()

# %%
def summarize_performance(epoch,g_model,d_model,dataset,latent_dim,n_samples = 132):

	x_real ,y_real = generate_real_samples(dataset,n_samples)
	_,acc_real = d_model.evaluate(x_real,y_real)

	x_fake,y_fake = generate_fake_samples(g_model,latent_dim,n_samples)
	_,acc_fake = d_model.evaluate(x_fake,y_fake)

	print(('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100)))
	save_plot(x_fake,epoch)
	filename = 'generator_model_%03d.h5' % (epoch+1)
	g_model.save(filename)

# %%
def train(g_model,d_model,gan_model, dataset ,latent_dim, n_epoch = 500, n_batch = 16):
	batch_per_epoch = int(dataset.shape[0]/n_batch)
	batch = int(n_batch/2)

	for i in range(n_epoch):
		for j in range (batch_per_epoch):

			x_real,y_real = generate_real_samples(dataset,batch)

			d_model_loss1,_ = d_model.train_on_batch(x_real,y_real)

			x_fake ,y_fake = generate_fake_samples(g_model,latent_dim,batch)

			d_model_loss2,_ =d_model.train_on_batch(x_fake,y_fake)

			x_gan = generate_latent_sample(latent_dim, n_batch)
			y_gan = np.ones((n_batch,1))

			g_model_loss = gan_model.train_on_batch(x_gan,y_gan)

			print('>%d, %d/%d, d1=%.3f, d2=%.3f g=%.3f'% 
                  (i+1, j+1, batch_per_epoch, d_model_loss1, d_model_loss2, g_model_loss))
		if (i+1) % 25 ==0 :
			summarize_performance(i,g_model,d_model,dataset,latent_dim)

# %%
xsam = []
CATEGORIES = [""]
training_data = []
IMG_SIZE = (256)

data_dir = "/content/drive/My Drive/images"

# %%
# for category in CATEGORIES:

path = os.path.join(data_dir) 

for img in tqdm(os.listdir(path)):
  img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_UNCHANGED)  # convert to array
  img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB )
  new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))  # resize to normalize data size
  training_data.append([new_array])  # add this to our training_data
# Out:
# 100%|██████████| 132/132 [01:39<00:00,  1.33it/s]

# %%
print(img_array)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
for features in training_data:
  
  xsam.append(features)
#  #   return xsam
print(np.array(xsam).shape)
print(np.array(training_data).shape)
# Out:
# (132, 1, 256, 256, 3)
# (132, 1, 256, 256, 3)

# %%
latent_dim = 4096
d_model = discriminator()
g_model = generator(latent_dim)
gan_model = gan(g_model,d_model)
d_model.summary()
g_model.summary()
print(np.array(training_data).shape)

dataset = load_real_data(xsam)
train(g_model,d_model,gan_model,dataset,latent_dim)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       224
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128, 128, 8)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 16)        64
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               524416
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,839,170
# Trainable params: 919,089
# Non-trainable params: 920,081
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 2, 2, 512)         33554944
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 4, 4, 256)         2097408
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 8, 8, 128)         524416
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 16, 16, 128)       262272
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 32, 32, 128)       262272
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 64, 64, 128)       262272
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 128, 128, 128)     262272
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 128, 128, 128)     0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 256, 256, 128)     262272
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 256, 256, 128)     512
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 256, 256, 128)     0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 3)       3459
# =================================================================
# Total params: 54,276,995
# Trainable params: 54,274,947
# Non-trainable params: 2,048
# _________________________________________________________________
# (132, 1, 256, 256, 3)
# (132, 256, 256, 3)
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# >1, 1/8, d1=1.207, d2=2.296 g=0.454
# >1, 2/8, d1=0.218, d2=1.269 g=0.782
# >1, 3/8, d1=0.707, d2=0.977 g=0.938
# >1, 4/8, d1=0.538, d2=0.825 g=0.910
# >1, 5/8, d1=0.706, d2=0.883 g=0.911
# >1, 6/8, d1=1.362, d2=0.347 g=0.206
# >1, 7/8, d1=0.513, d2=0.939 g=0.175
# >1, 8/8, d1=0.237, d2=0.609 g=0.206
# >2, 1/8, d1=0.943, d2=0.863 g=0.223
# >2, 2/8, d1=0.989, d2=0.891 g=0.160
# >2, 3/8, d1=1.718, d2=2.085 g=0.134
# >2, 4/8, d1=0.532, d2=1.660 g=0.697
# >2, 5/8, d1=1.366, d2=1.244 g=0.641
# >2, 6/8, d1=1.752, d2=1.472 g=0.571
# >2, 7/8, d1=1.656, d2=1.874 g=0.809
# >2, 8/8, d1=1.262, d2=2.103 g=1.140
# >3, 1/8, d1=1.539, d2=1.432 g=1.471
# >3, 2/8, d1=1.942, d2=1.835 g=1.116
# >3, 3/8, d1=1.663, d2=1.898 g=0.887
# >3, 4/8, d1=1.484, d2=1.685 g=1.161
# >3, 5/8, d1=0.989, d2=1.424 g=1.093
# >3, 6/8, d1=1.236, d2=1.351 g=0.990
# >3, 7/8, d1=1.555, d2=1.210 g=1.016
# >3, 8/8, d1=1.520, d2=1.704 g=0.815
# >4, 1/8, d1=1.114, d2=1.449 g=0.906
# >4, 2/8, d1=1.160, d2=1.166 g=1.214
# >4, 3/8, d1=1.319, d2=1.278 g=1.006
# >4, 4/8, d1=1.463, d2=1.249 g=0.940
# >4, 5/8, d1=1.153, d2=1.150 g=1.198
# >4, 6/8, d1=0.716, d2=0.934 g=1.572
# >4, 7/8, d1=0.918, d2=0.748 g=1.559
# >4, 8/8, d1=0.677, d2=0.995 g=0.913
# >5, 1/8, d1=1.535, d2=1.313 g=0.627
# >5, 2/8, d1=0.973, d2=1.425 g=0.620
# >5, 3/8, d1=1.482, d2=1.397 g=0.554
# >5, 4/8, d1=1.905, d2=1.218 g=0.782
# >5, 5/8, d1=2.130, d2=1.111 g=0.769
# >5, 6/8, d1=1.216, d2=1.150 g=1.077
# >5, 7/8, d1=1.025, d2=0.897 g=1.064
# >5, 8/8, d1=1.330, d2=0.925 g=1.083
# >6, 1/8, d1=1.108, d2=0.635 g=1.156
# >6, 2/8, d1=1.045, d2=0.763 g=1.414
# >6, 3/8, d1=1.126, d2=0.842 g=1.102
# >6, 4/8, d1=1.207, d2=0.727 g=1.010
# >6, 5/8, d1=1.047, d2=0.921 g=0.847
# >6, 6/8, d1=1.197, d2=1.077 g=0.645
# >6, 7/8, d1=1.688, d2=1.194 g=0.376
# >6, 8/8, d1=1.325, d2=1.673 g=0.490
# >7, 1/8, d1=1.301, d2=1.409 g=0.676
# >7, 2/8, d1=0.802, d2=0.774 g=1.018
# >7, 3/8, d1=0.607, d2=0.724 g=1.193
# >7, 4/8, d1=0.787, d2=0.676 g=1.344
# >7, 5/8, d1=0.748, d2=0.640 g=1.309
# >7, 6/8, d1=0.846, d2=0.619 g=1.038
# >7, 7/8, d1=1.278, d2=0.847 g=0.956
# >7, 8/8, d1=0.418, d2=0.658 g=0.709
# >8, 1/8, d1=0.838, d2=0.976 g=0.722
# >8, 2/8, d1=0.546, d2=0.801 g=0.633
# >8, 3/8, d1=0.780, d2=0.930 g=0.731
# >8, 4/8, d1=1.421, d2=1.060 g=0.704
# >8, 5/8, d1=1.056, d2=1.229 g=0.796
# >8, 6/8, d1=1.029, d2=1.179 g=1.147
# >8, 7/8, d1=1.134, d2=1.024 g=1.204
# >8, 8/8, d1=0.918, d2=0.869 g=1.268
# >9, 1/8, d1=1.210, d2=0.662 g=1.218
# >9, 2/8, d1=1.013, d2=1.038 g=0.869
# >9, 3/8, d1=0.978, d2=1.143 g=0.960
# >9, 4/8, d1=1.020, d2=0.827 g=0.931
# >9, 5/8, d1=1.314, d2=1.004 g=0.875
# >9, 6/8, d1=0.707, d2=0.930 g=1.012
# >9, 7/8, d1=0.760, d2=0.674 g=1.002
# >9, 8/8, d1=1.228, d2=0.878 g=1.008
# >10, 1/8, d1=0.951, d2=0.834 g=1.035
# >10, 2/8, d1=0.912, d2=0.805 g=1.130
# >10, 3/8, d1=0.709, d2=0.767 g=0.961
# >10, 4/8, d1=0.751, d2=0.720 g=0.851
# >10, 5/8, d1=1.186, d2=0.828 g=0.797
# >10, 6/8, d1=0.596, d2=0.754 g=0.654
# >10, 7/8, d1=0.563, d2=0.775 g=0.849
# >10, 8/8, d1=0.518, d2=0.834 g=0.945
# >11, 1/8, d1=0.618, d2=0.899 g=1.126
# >11, 2/8, d1=0.934, d2=0.666 g=1.159
# >11, 3/8, d1=1.118, d2=0.676 g=1.237
# >11, 4/8, d1=0.948, d2=0.612 g=1.308
# >11, 5/8, d1=0.643, d2=0.761 g=1.520
# >11, 6/8, d1=1.032, d2=0.585 g=1.332
# >11, 7/8, d1=0.720, d2=0.726 g=1.255
# >11, 8/8, d1=0.726, d2=0.601 g=1.362
# >12, 1/8, d1=0.919, d2=0.570 g=1.074
# >12, 2/8, d1=0.924, d2=0.654 g=0.662
# >12, 3/8, d1=0.439, d2=0.989 g=0.210
# >12, 4/8, d1=0.468, d2=1.403 g=0.335
# >12, 5/8, d1=0.841, d2=1.020 g=0.706
# >12, 6/8, d1=1.062, d2=0.557 g=1.304
# >12, 7/8, d1=0.739, d2=0.529 g=1.527
# >12, 8/8, d1=0.772, d2=0.491 g=1.731
# >13, 1/8, d1=0.420, d2=0.474 g=1.881
# >13, 2/8, d1=0.503, d2=0.344 g=1.604
# >13, 3/8, d1=0.290, d2=0.374 g=1.260
# >13, 4/8, d1=0.501, d2=0.570 g=0.855
# >13, 5/8, d1=0.433, d2=0.581 g=0.844
# >13, 6/8, d1=0.337, d2=0.558 g=0.876
# >13, 7/8, d1=0.873, d2=0.629 g=1.001
# >13, 8/8, d1=0.382, d2=0.628 g=1.071
# >14, 1/8, d1=1.163, d2=0.622 g=1.210
# >14, 2/8, d1=0.538, d2=0.575 g=1.282
# >14, 3/8, d1=0.483, d2=0.600 g=1.514
# >14, 4/8, d1=0.505, d2=0.493 g=1.672
# >14, 5/8, d1=0.754, d2=0.533 g=1.688
# >14, 6/8, d1=0.810, d2=0.513 g=1.704
# >14, 7/8, d1=0.370, d2=0.428 g=1.848
# >14, 8/8, d1=0.797, d2=0.402 g=1.835
# >15, 1/8, d1=0.843, d2=0.383 g=1.631
# >15, 2/8, d1=0.255, d2=0.420 g=1.690
# >15, 3/8, d1=0.853, d2=0.511 g=1.224
# >15, 4/8, d1=0.511, d2=0.706 g=1.137
# >15, 5/8, d1=0.276, d2=0.660 g=1.198
# >15, 6/8, d1=0.950, d2=0.807 g=0.958
# >15, 7/8, d1=0.567, d2=0.734 g=1.133
# >15, 8/8, d1=0.411, d2=0.514 g=1.483
# >16, 1/8, d1=0.638, d2=0.520 g=1.729
# >16, 2/8, d1=0.320, d2=0.508 g=1.853
# >16, 3/8, d1=0.515, d2=0.371 g=1.782
# >16, 4/8, d1=0.260, d2=0.315 g=1.490
# >16, 5/8, d1=0.175, d2=0.438 g=1.624
# >16, 6/8, d1=0.547, d2=0.521 g=1.761
# >16, 7/8, d1=0.190, d2=0.447 g=1.687
# >16, 8/8, d1=0.860, d2=0.448 g=1.793
# >17, 1/8, d1=0.625, d2=0.458 g=1.885
# >17, 2/8, d1=0.273, d2=0.381 g=2.053
# >17, 3/8, d1=0.299, d2=0.263 g=1.947
# >17, 4/8, d1=1.103, d2=0.496 g=1.780
# >17, 5/8, d1=0.894, d2=0.426 g=1.820
# >17, 6/8, d1=1.116, d2=0.390 g=1.714
# >17, 7/8, d1=0.095, d2=0.444 g=1.928
# >17, 8/8, d1=0.258, d2=0.309 g=2.113
# >18, 1/8, d1=0.248, d2=0.300 g=2.082
# >18, 2/8, d1=0.815, d2=0.401 g=1.948
# >18, 3/8, d1=0.064, d2=0.330 g=2.256
# >18, 4/8, d1=0.194, d2=0.197 g=2.420
# >18, 5/8, d1=0.347, d2=0.298 g=2.228
# >18, 6/8, d1=0.812, d2=0.376 g=2.174
# >18, 7/8, d1=0.095, d2=0.291 g=2.343
# >18, 8/8, d1=0.382, d2=0.287 g=2.032
# >19, 1/8, d1=0.376, d2=0.350 g=1.569
# >19, 2/8, d1=0.356, d2=0.462 g=1.276
# >19, 3/8, d1=0.117, d2=0.471 g=1.530
# >19, 4/8, d1=0.538, d2=0.598 g=1.792
# >19, 5/8, d1=0.388, d2=0.486 g=2.645
# >19, 6/8, d1=0.558, d2=0.619 g=2.060
# >19, 7/8, d1=0.552, d2=0.304 g=2.051
# >19, 8/8, d1=0.785, d2=0.113 g=2.430
# >20, 1/8, d1=1.452, d2=1.142 g=1.033
# >20, 2/8, d1=0.680, d2=1.338 g=1.388
# >20, 3/8, d1=0.517, d2=0.543 g=1.122
# >20, 4/8, d1=0.773, d2=1.213 g=2.245
# >20, 5/8, d1=1.371, d2=1.265 g=1.669
# >20, 6/8, d1=0.572, d2=0.571 g=1.752
# >20, 7/8, d1=0.605, d2=0.389 g=1.762
# >20, 8/8, d1=1.192, d2=0.737 g=1.804
# >21, 1/8, d1=0.834, d2=0.521 g=1.396
# >21, 2/8, d1=0.554, d2=0.451 g=0.830
# >21, 3/8, d1=0.537, d2=1.108 g=1.508
# >21, 4/8, d1=0.856, d2=0.760 g=1.486
# >21, 5/8, d1=0.917, d2=0.472 g=1.324
# >21, 6/8, d1=1.362, d2=1.109 g=1.062
# >21, 7/8, d1=1.523, d2=1.074 g=0.970
# >21, 8/8, d1=0.895, d2=1.253 g=1.321
# >22, 1/8, d1=0.579, d2=0.720 g=1.728
# >22, 2/8, d1=2.271, d2=0.521 g=1.821
# >22, 3/8, d1=1.560, d2=0.429 g=1.466
# >22, 4/8, d1=0.973, d2=0.823 g=1.028
# >22, 5/8, d1=1.102, d2=0.599 g=1.258
# >22, 6/8, d1=0.661, d2=0.831 g=1.048
# >22, 7/8, d1=0.455, d2=0.702 g=1.304
# >22, 8/8, d1=0.799, d2=0.439 g=1.108
# >23, 1/8, d1=0.489, d2=0.710 g=1.388
# >23, 2/8, d1=0.780, d2=0.872 g=1.093
# >23, 3/8, d1=0.959, d2=1.109 g=0.807
# >23, 4/8, d1=1.151, d2=0.819 g=1.799
# >23, 5/8, d1=0.946, d2=0.987 g=1.202
# >23, 6/8, d1=0.899, d2=0.887 g=0.768
# >23, 7/8, d1=1.071, d2=0.767 g=0.974
# >23, 8/8, d1=0.483, d2=1.058 g=1.010
# >24, 1/8, d1=0.705, d2=1.014 g=1.927
# >24, 2/8, d1=0.817, d2=0.887 g=1.398
# >24, 3/8, d1=1.516, d2=0.552 g=1.126
# >24, 4/8, d1=1.322, d2=0.900 g=0.994
# >24, 5/8, d1=0.498, d2=0.870 g=0.856
# >24, 6/8, d1=0.891, d2=1.008 g=1.209
# >24, 7/8, d1=1.077, d2=0.622 g=1.076
# >24, 8/8, d1=0.760, d2=0.752 g=0.914
# >25, 1/8, d1=0.950, d2=0.587 g=0.892
# >25, 2/8, d1=0.882, d2=1.051 g=0.688
# >25, 3/8, d1=0.651, d2=0.965 g=0.821
# >25, 4/8, d1=0.739, d2=0.738 g=0.710
# >25, 5/8, d1=0.677, d2=0.852 g=0.861
# >25, 6/8, d1=0.729, d2=0.908 g=1.032
# >25, 7/8, d1=0.704, d2=0.647 g=1.285
# >25, 8/8, d1=0.752, d2=0.722 g=1.143
# 132/132 [==============================] - 1s 4ms/step
# 132/132 [==============================] - 0s 887us/step
# >Accuracy real: 1%, fake: 86%
# >26, 1/8, d1=1.400, d2=0.785 g=0.851
# >26, 2/8, d1=0.851, d2=0.770 g=0.882
# >26, 3/8, d1=0.719, d2=0.702 g=0.950
# >26, 4/8, d1=0.910, d2=0.994 g=1.237
# >26, 5/8, d1=0.571, d2=0.698 g=1.080
# >26, 6/8, d1=1.055, d2=0.770 g=0.774
# >26, 7/8, d1=0.708, d2=0.878 g=0.884
# >26, 8/8, d1=0.942, d2=0.703 g=0.872
# >27, 1/8, d1=1.131, d2=0.754 g=0.935
# >27, 2/8, d1=0.810, d2=0.977 g=0.851
# >27, 3/8, d1=0.729, d2=1.008 g=1.096
# >27, 4/8, d1=1.068, d2=0.771 g=1.403
# >27, 5/8, d1=0.716, d2=0.886 g=1.046
# >27, 6/8, d1=0.813, d2=0.692 g=1.052
# >27, 7/8, d1=0.703, d2=0.853 g=0.864
# >27, 8/8, d1=0.831, d2=0.892 g=1.019
# >28, 1/8, d1=0.622, d2=0.886 g=0.861
# >28, 2/8, d1=0.642, d2=0.561 g=0.970
# >28, 3/8, d1=0.772, d2=1.208 g=1.142
# >28, 4/8, d1=1.101, d2=0.645 g=1.162
# >28, 5/8, d1=1.134, d2=1.069 g=0.905
# >28, 6/8, d1=0.875, d2=0.456 g=0.777
# >28, 7/8, d1=0.671, d2=0.995 g=1.008
# >28, 8/8, d1=0.888, d2=0.787 g=0.990
# >29, 1/8, d1=1.320, d2=0.667 g=1.497
# >29, 2/8, d1=0.962, d2=0.640 g=1.000
# >29, 3/8, d1=0.736, d2=0.887 g=1.222
# >29, 4/8, d1=0.754, d2=0.733 g=1.232
# >29, 5/8, d1=0.663, d2=0.664 g=1.209
# >29, 6/8, d1=1.172, d2=0.588 g=1.068
# >29, 7/8, d1=0.614, d2=0.526 g=1.114
# >29, 8/8, d1=0.866, d2=0.627 g=0.853
# >30, 1/8, d1=0.536, d2=0.660 g=0.969
# >30, 2/8, d1=0.665, d2=0.803 g=1.175
# >30, 3/8, d1=0.762, d2=0.582 g=1.015
# >30, 4/8, d1=0.864, d2=0.685 g=0.746
# >30, 5/8, d1=0.589, d2=0.934 g=0.617
# >30, 6/8, d1=0.758, d2=0.955 g=0.797
# >30, 7/8, d1=0.579, d2=0.665 g=0.650
# >30, 8/8, d1=0.938, d2=1.445 g=0.834
# >31, 1/8, d1=1.365, d2=1.347 g=0.637
# >31, 2/8, d1=0.845, d2=0.660 g=0.899
# >31, 3/8, d1=0.877, d2=0.830 g=0.871
# >31, 4/8, d1=0.559, d2=0.689 g=0.955
# >31, 5/8, d1=0.835, d2=0.693 g=0.962
# >31, 6/8, d1=0.778, d2=0.844 g=0.769
# >31, 7/8, d1=0.734, d2=1.043 g=0.981
# >31, 8/8, d1=0.755, d2=0.768 g=0.870
# >32, 1/8, d1=0.550, d2=0.778 g=0.854
# >32, 2/8, d1=0.635, d2=0.851 g=0.850
# >32, 3/8, d1=0.602, d2=0.751 g=0.919
# >32, 4/8, d1=0.823, d2=0.679 g=0.975
# >32, 5/8, d1=0.624, d2=0.675 g=0.946
# >32, 6/8, d1=0.876, d2=0.635 g=0.967
# >32, 7/8, d1=1.035, d2=0.714 g=1.065
# >32, 8/8, d1=0.858, d2=0.724 g=1.050
# >33, 1/8, d1=0.731, d2=0.509 g=1.069
# >33, 2/8, d1=0.616, d2=0.591 g=0.860
# >33, 3/8, d1=0.494, d2=0.724 g=1.190
# >33, 4/8, d1=0.543, d2=0.525 g=1.262
# >33, 5/8, d1=0.806, d2=0.422 g=1.313
# >33, 6/8, d1=0.461, d2=0.412 g=1.008
# >33, 7/8, d1=0.713, d2=0.693 g=0.752
# >33, 8/8, d1=0.663, d2=1.031 g=0.756
# >34, 1/8, d1=0.690, d2=0.600 g=0.909
# >34, 2/8, d1=0.684, d2=0.825 g=0.922
# >34, 3/8, d1=0.653, d2=0.675 g=0.795
# >34, 4/8, d1=1.357, d2=1.082 g=0.865
# >34, 5/8, d1=0.995, d2=1.108 g=1.097
# >34, 6/8, d1=1.194, d2=0.579 g=1.395
# >34, 7/8, d1=1.070, d2=0.489 g=1.267
# >34, 8/8, d1=0.781, d2=0.910 g=1.118
# >35, 1/8, d1=0.669, d2=0.825 g=0.952
# >35, 2/8, d1=0.922, d2=0.979 g=1.003
# >35, 3/8, d1=0.695, d2=0.751 g=1.157
# >35, 4/8, d1=0.780, d2=0.698 g=0.873
# >35, 5/8, d1=0.677, d2=0.881 g=0.838
# >35, 6/8, d1=0.858, d2=0.956 g=0.733
# >35, 7/8, d1=0.753, d2=0.847 g=0.723
# >35, 8/8, d1=0.548, d2=0.788 g=0.700
# >36, 1/8, d1=0.753, d2=0.895 g=0.747
# >36, 2/8, d1=0.516, d2=0.901 g=0.857
# >36, 3/8, d1=0.660, d2=1.127 g=1.153
# >36, 4/8, d1=0.814, d2=0.722 g=1.446
# >36, 5/8, d1=0.789, d2=0.759 g=1.269
# >36, 6/8, d1=0.906, d2=0.973 g=0.982
# >36, 7/8, d1=0.688, d2=0.772 g=0.998
# >36, 8/8, d1=0.524, d2=0.701 g=1.228
# >37, 1/8, d1=1.004, d2=0.693 g=1.017
# >37, 2/8, d1=0.817, d2=0.728 g=0.935
# >37, 3/8, d1=0.795, d2=0.969 g=0.780
# >37, 4/8, d1=0.579, d2=0.562 g=1.107
# >37, 5/8, d1=0.824, d2=0.726 g=1.064
# >37, 6/8, d1=0.771, d2=0.905 g=0.989
# >37, 7/8, d1=0.756, d2=1.012 g=1.132
# >37, 8/8, d1=0.657, d2=0.570 g=1.082
# >38, 1/8, d1=0.579, d2=0.690 g=0.863
# >38, 2/8, d1=0.658, d2=0.634 g=0.788
# >38, 3/8, d1=0.614, d2=0.797 g=0.955
# >38, 4/8, d1=0.853, d2=0.778 g=0.900
# >38, 5/8, d1=0.712, d2=0.694 g=1.023
# >38, 6/8, d1=0.666, d2=0.789 g=1.143
# >38, 7/8, d1=0.690, d2=0.758 g=1.036
# >38, 8/8, d1=1.050, d2=0.802 g=0.851
# >39, 1/8, d1=0.934, d2=0.805 g=0.868
# >39, 2/8, d1=1.058, d2=0.814 g=0.769
# >39, 3/8, d1=1.035, d2=0.914 g=1.110
# >39, 4/8, d1=0.771, d2=0.715 g=1.102
# >39, 5/8, d1=0.755, d2=0.555 g=1.053
# >39, 6/8, d1=0.890, d2=0.615 g=0.661
# >39, 7/8, d1=0.720, d2=1.026 g=0.772
# >39, 8/8, d1=0.946, d2=1.024 g=0.913
# >40, 1/8, d1=0.701, d2=0.943 g=0.896
# >40, 2/8, d1=0.737, d2=0.860 g=1.018
# >40, 3/8, d1=0.585, d2=0.627 g=0.912
# >40, 4/8, d1=1.096, d2=0.768 g=1.108
# >40, 5/8, d1=1.046, d2=0.658 g=0.782
# >40, 6/8, d1=0.635, d2=1.070 g=0.961
# >40, 7/8, d1=1.022, d2=0.739 g=1.080
# >40, 8/8, d1=0.854, d2=0.591 g=0.982
# >41, 1/8, d1=0.713, d2=0.935 g=1.035
# >41, 2/8, d1=0.710, d2=0.592 g=0.975
# >41, 3/8, d1=0.753, d2=0.732 g=0.899
# >41, 4/8, d1=0.827, d2=0.942 g=0.991
# >41, 5/8, d1=0.848, d2=0.704 g=0.957
# >41, 6/8, d1=0.936, d2=0.676 g=0.847
# >41, 7/8, d1=0.826, d2=0.728 g=0.899
# >41, 8/8, d1=0.849, d2=0.646 g=1.059
# >42, 1/8, d1=0.509, d2=0.433 g=1.195
# >42, 2/8, d1=0.874, d2=0.599 g=1.015
# >42, 3/8, d1=0.426, d2=0.718 g=1.160
# >42, 4/8, d1=0.741, d2=0.396 g=0.977
# >42, 5/8, d1=0.568, d2=0.501 g=0.718
# >42, 6/8, d1=0.704, d2=0.739 g=0.579
# >42, 7/8, d1=0.583, d2=1.041 g=0.628
# >42, 8/8, d1=1.178, d2=1.106 g=0.754
# >43, 1/8, d1=0.979, d2=1.184 g=0.815
# >43, 2/8, d1=0.652, d2=1.017 g=1.093
# >43, 3/8, d1=0.901, d2=0.545 g=1.363
# >43, 4/8, d1=0.622, d2=0.410 g=1.163
# >43, 5/8, d1=0.775, d2=0.633 g=1.014
# >43, 6/8, d1=0.561, d2=0.519 g=0.875
# >43, 7/8, d1=0.372, d2=0.613 g=0.773
# >43, 8/8, d1=0.518, d2=0.735 g=0.711
# >44, 1/8, d1=0.520, d2=0.815 g=0.716
# >44, 2/8, d1=0.779, d2=0.680 g=0.829
# >44, 3/8, d1=0.658, d2=0.757 g=0.896
# >44, 4/8, d1=0.913, d2=0.684 g=0.889
# >44, 5/8, d1=0.895, d2=0.752 g=0.833
# >44, 6/8, d1=0.827, d2=0.902 g=0.958
# >44, 7/8, d1=0.831, d2=0.869 g=0.851
# >44, 8/8, d1=0.934, d2=0.716 g=0.847
# >45, 1/8, d1=1.068, d2=0.777 g=0.903
# >45, 2/8, d1=0.857, d2=0.874 g=0.832
# >45, 3/8, d1=0.797, d2=0.579 g=0.981
# >45, 4/8, d1=0.769, d2=0.825 g=0.861
# >45, 5/8, d1=0.761, d2=0.714 g=0.930
# >45, 6/8, d1=0.841, d2=0.655 g=0.890
# >45, 7/8, d1=0.577, d2=0.594 g=0.851
# >45, 8/8, d1=0.782, d2=0.821 g=0.899
# >46, 1/8, d1=0.819, d2=0.657 g=0.846
# >46, 2/8, d1=0.793, d2=0.929 g=0.772
# >46, 3/8, d1=0.632, d2=0.852 g=1.084
# >46, 4/8, d1=0.863, d2=0.661 g=0.891
# >46, 5/8, d1=1.119, d2=0.588 g=1.091
# >46, 6/8, d1=0.843, d2=0.636 g=0.892
# >46, 7/8, d1=0.923, d2=0.847 g=0.873
# >46, 8/8, d1=0.709, d2=0.857 g=1.046
# >47, 1/8, d1=0.961, d2=0.627 g=0.739
# >47, 2/8, d1=0.761, d2=0.943 g=0.878
# >47, 3/8, d1=0.754, d2=0.800 g=0.936
# >47, 4/8, d1=0.721, d2=0.734 g=0.910
# >47, 5/8, d1=0.935, d2=0.992 g=0.842
# >47, 6/8, d1=0.899, d2=0.954 g=0.670
# >47, 7/8, d1=0.658, d2=0.833 g=1.056
# >47, 8/8, d1=0.652, d2=0.672 g=1.003
# >48, 1/8, d1=0.906, d2=0.875 g=0.913
# >48, 2/8, d1=0.851, d2=0.678 g=0.964
# >48, 3/8, d1=0.695, d2=0.546 g=1.012
# >48, 4/8, d1=0.483, d2=0.614 g=1.136
# >48, 5/8, d1=0.556, d2=0.492 g=1.191
# >48, 6/8, d1=0.599, d2=0.508 g=1.230
# >48, 7/8, d1=0.485, d2=0.752 g=1.290
# >48, 8/8, d1=0.502, d2=0.836 g=0.907
# >49, 1/8, d1=0.514, d2=0.943 g=0.853
# >49, 2/8, d1=0.586, d2=0.725 g=1.035
# >49, 3/8, d1=0.805, d2=0.596 g=1.103
# >49, 4/8, d1=0.653, d2=0.746 g=0.852
# >49, 5/8, d1=0.710, d2=0.749 g=1.008
# >49, 6/8, d1=0.804, d2=0.698 g=0.941
# >49, 7/8, d1=0.637, d2=0.623 g=0.771
# >49, 8/8, d1=0.800, d2=0.923 g=0.782
# >50, 1/8, d1=0.958, d2=0.813 g=0.825
# >50, 2/8, d1=0.619, d2=0.700 g=0.777
# >50, 3/8, d1=0.913, d2=0.725 g=0.918
# >50, 4/8, d1=0.697, d2=0.673 g=0.621
# >50, 5/8, d1=0.494, d2=0.744 g=0.861
# >50, 6/8, d1=0.734, d2=0.908 g=0.937
# >50, 7/8, d1=0.694, d2=0.689 g=0.756
# >50, 8/8, d1=0.684, d2=0.827 g=0.871
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 798us/step
# >Accuracy real: 60%, fake: 30%
# >51, 1/8, d1=0.595, d2=1.106 g=0.721
# >51, 2/8, d1=0.729, d2=0.871 g=0.924
# >51, 3/8, d1=0.911, d2=0.816 g=0.848
# >51, 4/8, d1=0.917, d2=0.762 g=0.764
# >51, 5/8, d1=0.605, d2=0.783 g=0.810
# >51, 6/8, d1=0.525, d2=0.822 g=0.767
# >51, 7/8, d1=0.575, d2=0.852 g=0.875
# >51, 8/8, d1=0.799, d2=0.522 g=0.814
# >52, 1/8, d1=0.885, d2=1.022 g=0.720
# >52, 2/8, d1=0.567, d2=0.824 g=0.864
# >52, 3/8, d1=1.560, d2=0.542 g=0.928
# >52, 4/8, d1=1.090, d2=1.006 g=0.787
# >52, 5/8, d1=0.723, d2=0.803 g=1.095
# >52, 6/8, d1=1.088, d2=0.465 g=1.095
# >52, 7/8, d1=1.092, d2=0.678 g=0.784
# >52, 8/8, d1=0.836, d2=0.833 g=0.965
# >53, 1/8, d1=0.971, d2=0.720 g=0.855
# >53, 2/8, d1=0.992, d2=0.728 g=0.793
# >53, 3/8, d1=0.712, d2=0.610 g=0.846
# >53, 4/8, d1=0.812, d2=0.706 g=0.860
# >53, 5/8, d1=0.802, d2=0.716 g=1.073
# >53, 6/8, d1=0.652, d2=0.650 g=0.908
# >53, 7/8, d1=0.673, d2=0.618 g=0.911
# >53, 8/8, d1=0.608, d2=0.640 g=0.916
# >54, 1/8, d1=0.524, d2=0.634 g=0.905
# >54, 2/8, d1=0.767, d2=0.561 g=0.919
# >54, 3/8, d1=1.018, d2=0.687 g=0.843
# >54, 4/8, d1=0.799, d2=0.936 g=0.732
# >54, 5/8, d1=0.707, d2=0.862 g=0.943
# >54, 6/8, d1=0.681, d2=0.683 g=1.022
# >54, 7/8, d1=0.864, d2=0.706 g=1.038
# >54, 8/8, d1=0.646, d2=0.654 g=0.887
# >55, 1/8, d1=0.742, d2=0.613 g=0.857
# >55, 2/8, d1=0.785, d2=0.678 g=0.773
# >55, 3/8, d1=0.684, d2=0.679 g=0.807
# >55, 4/8, d1=0.727, d2=0.711 g=0.794
# >55, 5/8, d1=0.656, d2=0.564 g=0.955
# >55, 6/8, d1=0.583, d2=0.688 g=0.772
# >55, 7/8, d1=0.710, d2=0.874 g=0.699
# >55, 8/8, d1=0.746, d2=1.124 g=0.584
# >56, 1/8, d1=0.609, d2=0.932 g=0.676
# >56, 2/8, d1=0.872, d2=0.699 g=0.910
# >56, 3/8, d1=0.970, d2=0.732 g=1.078
# >56, 4/8, d1=0.998, d2=0.642 g=1.058
# >56, 5/8, d1=0.776, d2=0.632 g=1.049
# >56, 6/8, d1=0.827, d2=0.640 g=1.028
# >56, 7/8, d1=0.784, d2=0.641 g=1.008
# >56, 8/8, d1=0.678, d2=0.750 g=0.896
# >57, 1/8, d1=0.509, d2=0.773 g=1.026
# >57, 2/8, d1=0.842, d2=0.805 g=0.917
# >57, 3/8, d1=1.086, d2=0.852 g=0.872
# >57, 4/8, d1=0.520, d2=0.748 g=0.940
# >57, 5/8, d1=0.728, d2=0.508 g=1.049
# >57, 6/8, d1=0.757, d2=0.787 g=1.069
# >57, 7/8, d1=0.655, d2=0.672 g=1.032
# >57, 8/8, d1=0.619, d2=0.520 g=1.031
# >58, 1/8, d1=0.718, d2=0.600 g=1.141
# >58, 2/8, d1=0.687, d2=0.804 g=0.895
# >58, 3/8, d1=0.833, d2=0.922 g=0.754
# >58, 4/8, d1=0.742, d2=0.935 g=0.749
# >58, 5/8, d1=0.862, d2=0.798 g=0.885
# >58, 6/8, d1=0.807, d2=0.844 g=0.975
# >58, 7/8, d1=0.813, d2=0.798 g=0.906
# >58, 8/8, d1=0.946, d2=0.686 g=1.006
# >59, 1/8, d1=0.744, d2=0.700 g=1.092
# >59, 2/8, d1=0.923, d2=0.733 g=1.191
# >59, 3/8, d1=0.756, d2=0.402 g=1.139
# >59, 4/8, d1=0.712, d2=0.476 g=1.079
# >59, 5/8, d1=0.735, d2=0.777 g=0.904
# >59, 6/8, d1=0.588, d2=0.833 g=1.018
# >59, 7/8, d1=0.618, d2=0.574 g=1.009
# >59, 8/8, d1=0.499, d2=0.693 g=1.073
# >60, 1/8, d1=0.746, d2=0.785 g=1.185
# >60, 2/8, d1=0.693, d2=0.577 g=1.310
# >60, 3/8, d1=0.505, d2=0.549 g=1.576
# >60, 4/8, d1=0.563, d2=0.592 g=1.744
# >60, 5/8, d1=0.295, d2=0.388 g=2.006
# >60, 6/8, d1=0.663, d2=0.421 g=1.431
# >60, 7/8, d1=0.855, d2=1.512 g=0.633
# >60, 8/8, d1=0.563, d2=0.908 g=0.986
# >61, 1/8, d1=0.573, d2=0.634 g=0.897
# >61, 2/8, d1=0.784, d2=0.708 g=0.970
# >61, 3/8, d1=0.955, d2=0.855 g=0.756
# >61, 4/8, d1=0.685, d2=1.050 g=0.739
# >61, 5/8, d1=0.701, d2=0.863 g=0.994
# >61, 6/8, d1=0.762, d2=0.590 g=1.099
# >61, 7/8, d1=0.700, d2=0.632 g=1.129
# >61, 8/8, d1=0.765, d2=0.416 g=1.177
# >62, 1/8, d1=0.576, d2=0.562 g=1.070
# >62, 2/8, d1=0.884, d2=0.630 g=0.895
# >62, 3/8, d1=0.574, d2=0.690 g=0.949
# >62, 4/8, d1=0.647, d2=0.560 g=0.801
# >62, 5/8, d1=0.564, d2=0.669 g=0.955
# >62, 6/8, d1=0.734, d2=0.572 g=0.904
# >62, 7/8, d1=0.650, d2=0.839 g=0.960
# >62, 8/8, d1=0.784, d2=0.563 g=0.999
# >63, 1/8, d1=0.587, d2=0.649 g=1.095
# >63, 2/8, d1=0.992, d2=0.784 g=0.771
# >63, 3/8, d1=0.606, d2=0.690 g=0.917
# >63, 4/8, d1=0.538, d2=0.563 g=0.893
# >63, 5/8, d1=0.631, d2=0.872 g=1.079
# >63, 6/8, d1=0.612, d2=0.652 g=1.155
# >63, 7/8, d1=0.769, d2=0.304 g=1.088
# >63, 8/8, d1=0.639, d2=0.722 g=0.900
# >64, 1/8, d1=0.774, d2=0.980 g=0.986
# >64, 2/8, d1=0.475, d2=0.613 g=1.060
# >64, 3/8, d1=0.641, d2=0.417 g=0.931
# >64, 4/8, d1=0.702, d2=0.939 g=1.000
# >64, 5/8, d1=0.762, d2=0.677 g=0.820
# >64, 6/8, d1=0.481, d2=0.923 g=0.906
# >64, 7/8, d1=1.034, d2=0.693 g=0.889
# >64, 8/8, d1=0.447, d2=0.774 g=0.927
# >65, 1/8, d1=0.637, d2=0.707 g=0.880
# >65, 2/8, d1=0.860, d2=0.528 g=0.863
# >65, 3/8, d1=0.621, d2=0.606 g=0.972
# >65, 4/8, d1=0.720, d2=0.527 g=0.973
# >65, 5/8, d1=0.800, d2=0.723 g=1.004
# >65, 6/8, d1=0.670, d2=0.505 g=1.016
# >65, 7/8, d1=0.841, d2=0.844 g=0.839
# >65, 8/8, d1=0.743, d2=0.855 g=0.957
# >66, 1/8, d1=0.699, d2=0.774 g=1.171
# >66, 2/8, d1=0.584, d2=0.620 g=1.106
# >66, 3/8, d1=0.491, d2=0.664 g=1.042
# >66, 4/8, d1=0.687, d2=0.579 g=0.808
# >66, 5/8, d1=0.517, d2=0.698 g=0.933
# >66, 6/8, d1=0.579, d2=0.626 g=0.917
# >66, 7/8, d1=0.599, d2=0.603 g=1.174
# >66, 8/8, d1=0.595, d2=0.471 g=1.217
# >67, 1/8, d1=0.484, d2=0.639 g=1.034
# >67, 2/8, d1=0.763, d2=0.920 g=0.966
# >67, 3/8, d1=0.708, d2=0.775 g=0.983
# >67, 4/8, d1=0.787, d2=0.505 g=0.746
# >67, 5/8, d1=0.810, d2=0.808 g=0.839
# >67, 6/8, d1=0.719, d2=0.994 g=0.908
# >67, 7/8, d1=0.606, d2=0.896 g=1.098
# >67, 8/8, d1=0.868, d2=0.516 g=1.064
# >68, 1/8, d1=0.693, d2=0.595 g=1.023
# >68, 2/8, d1=0.858, d2=0.811 g=0.868
# >68, 3/8, d1=0.854, d2=0.743 g=1.059
# >68, 4/8, d1=0.699, d2=0.559 g=0.980
# >68, 5/8, d1=0.556, d2=0.821 g=0.959
# >68, 6/8, d1=0.736, d2=0.775 g=0.848
# >68, 7/8, d1=0.942, d2=0.913 g=0.837
# >68, 8/8, d1=0.643, d2=0.796 g=0.868
# >69, 1/8, d1=0.847, d2=0.668 g=0.881
# >69, 2/8, d1=0.694, d2=1.130 g=0.968
# >69, 3/8, d1=0.824, d2=0.734 g=0.996
# >69, 4/8, d1=0.856, d2=0.681 g=1.206
# >69, 5/8, d1=1.111, d2=0.660 g=1.240
# >69, 6/8, d1=0.727, d2=0.635 g=1.383
# >69, 7/8, d1=0.961, d2=0.390 g=1.000
# >69, 8/8, d1=0.504, d2=0.673 g=1.071
# >70, 1/8, d1=0.531, d2=0.722 g=1.145
# >70, 2/8, d1=0.873, d2=0.644 g=0.909
# >70, 3/8, d1=0.549, d2=0.792 g=0.954
# >70, 4/8, d1=0.737, d2=0.788 g=0.886
# >70, 5/8, d1=0.533, d2=0.803 g=0.963
# >70, 6/8, d1=0.532, d2=0.585 g=0.957
# >70, 7/8, d1=0.891, d2=0.779 g=1.000
# >70, 8/8, d1=0.616, d2=0.811 g=1.149
# >71, 1/8, d1=0.590, d2=0.382 g=0.827
# >71, 2/8, d1=0.629, d2=0.805 g=0.924
# >71, 3/8, d1=0.729, d2=0.683 g=1.101
# >71, 4/8, d1=0.646, d2=0.639 g=1.047
# >71, 5/8, d1=0.529, d2=0.858 g=1.202
# >71, 6/8, d1=0.577, d2=0.439 g=1.107
# >71, 7/8, d1=0.824, d2=0.423 g=1.017
# >71, 8/8, d1=0.431, d2=0.552 g=1.051
# >72, 1/8, d1=1.093, d2=0.700 g=0.483
# >72, 2/8, d1=0.415, d2=1.049 g=0.649
# >72, 3/8, d1=0.835, d2=0.979 g=0.792
# >72, 4/8, d1=0.715, d2=0.758 g=0.952
# >72, 5/8, d1=0.923, d2=0.580 g=0.733
# >72, 6/8, d1=0.774, d2=0.796 g=0.792
# >72, 7/8, d1=0.569, d2=0.643 g=0.877
# >72, 8/8, d1=0.742, d2=0.383 g=0.982
# >73, 1/8, d1=0.797, d2=0.658 g=0.854
# >73, 2/8, d1=0.633, d2=0.696 g=0.964
# >73, 3/8, d1=0.489, d2=0.599 g=1.110
# >73, 4/8, d1=0.496, d2=0.534 g=1.189
# >73, 5/8, d1=0.494, d2=0.575 g=1.176
# >73, 6/8, d1=0.487, d2=0.467 g=1.209
# >73, 7/8, d1=0.616, d2=0.489 g=1.115
# >73, 8/8, d1=0.720, d2=0.577 g=0.951
# >74, 1/8, d1=0.802, d2=0.648 g=0.867
# >74, 2/8, d1=1.347, d2=0.759 g=1.008
# >74, 3/8, d1=0.730, d2=0.604 g=0.907
# >74, 4/8, d1=0.535, d2=0.442 g=1.004
# >74, 5/8, d1=0.653, d2=0.536 g=0.697
# >74, 6/8, d1=0.500, d2=0.968 g=0.612
# >74, 7/8, d1=0.428, d2=0.618 g=0.677
# >74, 8/8, d1=0.601, d2=0.762 g=0.947
# >75, 1/8, d1=1.014, d2=0.689 g=1.007
# >75, 2/8, d1=0.534, d2=0.557 g=0.959
# >75, 3/8, d1=0.678, d2=0.675 g=1.032
# >75, 4/8, d1=1.192, d2=0.697 g=0.777
# >75, 5/8, d1=0.725, d2=0.699 g=0.963
# >75, 6/8, d1=0.737, d2=0.577 g=1.106
# >75, 7/8, d1=1.134, d2=0.630 g=0.826
# >75, 8/8, d1=0.682, d2=0.621 g=0.884
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 861us/step
# >Accuracy real: 48%, fake: 11%
# >76, 1/8, d1=0.727, d2=0.668 g=0.695
# >76, 2/8, d1=0.483, d2=0.407 g=0.931
# >76, 3/8, d1=0.986, d2=0.742 g=0.643
# >76, 4/8, d1=0.703, d2=0.543 g=0.718
# >76, 5/8, d1=0.511, d2=0.936 g=1.147
# >76, 6/8, d1=0.339, d2=0.629 g=1.115
# >76, 7/8, d1=0.866, d2=0.860 g=0.977
# >76, 8/8, d1=0.562, d2=0.837 g=0.995
# >77, 1/8, d1=0.782, d2=0.537 g=0.964
# >77, 2/8, d1=0.840, d2=0.433 g=1.013
# >77, 3/8, d1=0.518, d2=0.718 g=1.187
# >77, 4/8, d1=0.440, d2=0.501 g=1.466
# >77, 5/8, d1=0.432, d2=0.277 g=1.611
# >77, 6/8, d1=0.417, d2=0.244 g=1.281
# >77, 7/8, d1=0.305, d2=0.478 g=1.264
# >77, 8/8, d1=0.422, d2=0.263 g=1.125
# >78, 1/8, d1=0.170, d2=0.700 g=1.071
# >78, 2/8, d1=0.421, d2=0.697 g=1.204
# >78, 3/8, d1=0.866, d2=0.590 g=1.316
# >78, 4/8, d1=0.527, d2=0.504 g=1.338
# >78, 5/8, d1=0.406, d2=0.584 g=1.435
# >78, 6/8, d1=0.688, d2=0.653 g=1.327
# >78, 7/8, d1=0.654, d2=0.941 g=1.369
# >78, 8/8, d1=0.695, d2=0.509 g=1.425
# >79, 1/8, d1=0.767, d2=0.452 g=1.125
# >79, 2/8, d1=0.486, d2=0.580 g=1.141
# >79, 3/8, d1=0.512, d2=0.688 g=1.117
# >79, 4/8, d1=0.413, d2=0.580 g=1.387
# >79, 5/8, d1=0.617, d2=0.841 g=1.033
# >79, 6/8, d1=0.581, d2=0.801 g=1.124
# >79, 7/8, d1=0.709, d2=0.844 g=0.921
# >79, 8/8, d1=0.598, d2=0.652 g=1.105
# >80, 1/8, d1=0.729, d2=0.393 g=1.240
# >80, 2/8, d1=0.673, d2=0.615 g=1.205
# >80, 3/8, d1=0.454, d2=0.435 g=1.443
# >80, 4/8, d1=0.599, d2=0.674 g=1.157
# >80, 5/8, d1=0.718, d2=0.716 g=0.820
# >80, 6/8, d1=0.429, d2=0.785 g=1.080
# >80, 7/8, d1=0.373, d2=0.599 g=1.328
# >80, 8/8, d1=0.951, d2=0.426 g=1.021
# >81, 1/8, d1=0.542, d2=0.874 g=1.370
# >81, 2/8, d1=0.455, d2=0.955 g=1.196
# >81, 3/8, d1=0.948, d2=0.629 g=1.020
# >81, 4/8, d1=1.842, d2=0.600 g=0.997
# >81, 5/8, d1=0.801, d2=0.570 g=0.929
# >81, 6/8, d1=0.500, d2=0.457 g=1.018
# >81, 7/8, d1=0.714, d2=0.995 g=1.017
# >81, 8/8, d1=0.430, d2=0.775 g=1.393
# >82, 1/8, d1=0.595, d2=0.446 g=1.356
# >82, 2/8, d1=0.404, d2=0.539 g=1.560
# >82, 3/8, d1=0.974, d2=0.610 g=1.290
# >82, 4/8, d1=0.625, d2=0.793 g=1.153
# >82, 5/8, d1=0.454, d2=0.529 g=1.213
# >82, 6/8, d1=0.881, d2=0.558 g=0.906
# >82, 7/8, d1=0.328, d2=0.652 g=0.976
# >82, 8/8, d1=0.618, d2=0.772 g=1.090
# >83, 1/8, d1=0.620, d2=0.751 g=1.226
# >83, 2/8, d1=0.523, d2=0.598 g=1.218
# >83, 3/8, d1=1.068, d2=0.646 g=1.096
# >83, 4/8, d1=1.202, d2=0.838 g=1.080
# >83, 5/8, d1=0.809, d2=0.766 g=1.176
# >83, 6/8, d1=1.036, d2=0.419 g=0.902
# >83, 7/8, d1=0.470, d2=0.836 g=1.090
# >83, 8/8, d1=0.513, d2=0.521 g=1.201
# >84, 1/8, d1=0.591, d2=0.478 g=1.543
# >84, 2/8, d1=0.649, d2=0.509 g=1.430
# >84, 3/8, d1=0.643, d2=0.620 g=1.196
# >84, 4/8, d1=0.610, d2=0.507 g=1.122
# >84, 5/8, d1=0.919, d2=0.922 g=0.998
# >84, 6/8, d1=0.551, d2=0.544 g=1.221
# >84, 7/8, d1=0.719, d2=0.763 g=1.034
# >84, 8/8, d1=0.722, d2=0.825 g=1.038
# >85, 1/8, d1=0.950, d2=0.519 g=0.873
# >85, 2/8, d1=0.744, d2=0.972 g=1.291
# >85, 3/8, d1=0.812, d2=0.515 g=1.334
# >85, 4/8, d1=0.665, d2=0.681 g=1.141
# >85, 5/8, d1=0.659, d2=0.761 g=1.135
# >85, 6/8, d1=0.656, d2=0.502 g=1.249
# >85, 7/8, d1=0.557, d2=0.432 g=1.030
# >85, 8/8, d1=0.330, d2=0.931 g=1.172
# >86, 1/8, d1=0.659, d2=0.780 g=1.210
# >86, 2/8, d1=0.461, d2=0.388 g=1.167
# >86, 3/8, d1=1.081, d2=0.759 g=0.911
# >86, 4/8, d1=0.465, d2=0.753 g=1.065
# >86, 5/8, d1=0.415, d2=0.666 g=1.169
# >86, 6/8, d1=0.525, d2=0.654 g=1.434
# >86, 7/8, d1=0.894, d2=0.505 g=1.141
# >86, 8/8, d1=0.716, d2=0.797 g=1.124
# >87, 1/8, d1=0.669, d2=0.803 g=1.201
# >87, 2/8, d1=0.693, d2=0.453 g=1.107
# >87, 3/8, d1=0.603, d2=0.591 g=1.118
# >87, 4/8, d1=0.506, d2=0.707 g=1.259
# >87, 5/8, d1=0.923, d2=0.576 g=1.303
# >87, 6/8, d1=0.573, d2=0.712 g=1.116
# >87, 7/8, d1=0.594, d2=0.689 g=1.223
# >87, 8/8, d1=0.695, d2=0.643 g=1.280
# >88, 1/8, d1=0.617, d2=0.665 g=1.464
# >88, 2/8, d1=0.872, d2=0.768 g=1.275
# >88, 3/8, d1=0.462, d2=0.571 g=1.303
# >88, 4/8, d1=0.957, d2=0.480 g=1.032
# >88, 5/8, d1=0.462, d2=0.623 g=1.160
# >88, 6/8, d1=0.562, d2=0.562 g=1.518
# >88, 7/8, d1=0.664, d2=0.387 g=1.474
# >88, 8/8, d1=0.627, d2=0.420 g=1.316
# >89, 1/8, d1=0.585, d2=0.469 g=1.140
# >89, 2/8, d1=0.510, d2=0.641 g=1.257
# >89, 3/8, d1=0.526, d2=0.451 g=1.260
# >89, 4/8, d1=0.603, d2=0.827 g=1.073
# >89, 5/8, d1=0.468, d2=0.543 g=1.347
# >89, 6/8, d1=1.489, d2=1.030 g=1.025
# >89, 7/8, d1=0.573, d2=0.850 g=1.062
# >89, 8/8, d1=0.524, d2=0.679 g=1.346
# >90, 1/8, d1=0.679, d2=0.535 g=1.400
# >90, 2/8, d1=0.757, d2=0.390 g=1.177
# >90, 3/8, d1=0.563, d2=0.660 g=1.221
# >90, 4/8, d1=0.440, d2=0.572 g=1.183
# >90, 5/8, d1=0.480, d2=0.519 g=1.158
# >90, 6/8, d1=0.567, d2=0.701 g=1.135
# >90, 7/8, d1=0.466, d2=0.749 g=1.353
# >90, 8/8, d1=0.588, d2=0.503 g=1.439
# >91, 1/8, d1=0.877, d2=0.749 g=1.141
# >91, 2/8, d1=0.451, d2=0.384 g=1.354
# >91, 3/8, d1=0.304, d2=0.668 g=1.314
# >91, 4/8, d1=0.863, d2=0.602 g=1.279
# >91, 5/8, d1=0.596, d2=0.677 g=1.259
# >91, 6/8, d1=0.651, d2=0.675 g=1.381
# >91, 7/8, d1=0.733, d2=0.653 g=1.456
# >91, 8/8, d1=0.614, d2=0.421 g=1.218
# >92, 1/8, d1=0.693, d2=0.746 g=1.196
# >92, 2/8, d1=1.323, d2=0.538 g=1.098
# >92, 3/8, d1=0.447, d2=0.672 g=1.131
# >92, 4/8, d1=0.559, d2=0.566 g=0.925
# >92, 5/8, d1=0.419, d2=0.570 g=1.165
# >92, 6/8, d1=0.420, d2=0.454 g=1.523
# >92, 7/8, d1=1.014, d2=0.526 g=1.571
# >92, 8/8, d1=0.702, d2=0.934 g=1.130
# >93, 1/8, d1=0.450, d2=0.552 g=1.217
# >93, 2/8, d1=0.751, d2=0.746 g=1.027
# >93, 3/8, d1=0.450, d2=0.681 g=0.836
# >93, 4/8, d1=0.420, d2=0.716 g=1.203
# >93, 5/8, d1=0.492, d2=0.644 g=1.297
# >93, 6/8, d1=0.934, d2=0.696 g=1.244
# >93, 7/8, d1=0.742, d2=0.481 g=1.634
# >93, 8/8, d1=0.516, d2=0.519 g=1.534
# >94, 1/8, d1=0.891, d2=0.585 g=1.403
# >94, 2/8, d1=0.405, d2=0.661 g=1.296
# >94, 3/8, d1=0.528, d2=0.513 g=0.975
# >94, 4/8, d1=0.894, d2=0.781 g=1.266
# >94, 5/8, d1=0.702, d2=0.666 g=1.140
# >94, 6/8, d1=0.854, d2=0.556 g=0.748
# >94, 7/8, d1=0.823, d2=1.204 g=0.883
# >94, 8/8, d1=0.545, d2=0.837 g=1.104
# >95, 1/8, d1=1.011, d2=0.477 g=1.325
# >95, 2/8, d1=0.611, d2=1.284 g=1.068
# >95, 3/8, d1=0.823, d2=0.446 g=1.253
# >95, 4/8, d1=0.909, d2=0.865 g=1.087
# >95, 5/8, d1=0.639, d2=0.609 g=1.031
# >95, 6/8, d1=0.582, d2=0.344 g=0.991
# >95, 7/8, d1=0.611, d2=0.717 g=0.887
# >95, 8/8, d1=0.554, d2=0.675 g=1.126
# >96, 1/8, d1=0.387, d2=0.840 g=1.242
# >96, 2/8, d1=0.833, d2=0.456 g=1.395
# >96, 3/8, d1=0.888, d2=0.520 g=1.270
# >96, 4/8, d1=0.741, d2=0.790 g=1.264
# >96, 5/8, d1=0.619, d2=0.685 g=1.132
# >96, 6/8, d1=0.305, d2=0.466 g=1.314
# >96, 7/8, d1=0.854, d2=0.555 g=1.472
# >96, 8/8, d1=0.673, d2=0.618 g=1.282
# >97, 1/8, d1=0.437, d2=0.452 g=1.408
# >97, 2/8, d1=0.543, d2=0.527 g=1.586
# >97, 3/8, d1=0.625, d2=0.518 g=1.486
# >97, 4/8, d1=0.378, d2=0.397 g=1.458
# >97, 5/8, d1=0.643, d2=0.438 g=1.462
# >97, 6/8, d1=1.066, d2=0.611 g=1.168
# >97, 7/8, d1=0.446, d2=0.744 g=1.516
# >97, 8/8, d1=0.564, d2=0.553 g=1.296
# >98, 1/8, d1=0.737, d2=0.548 g=1.184
# >98, 2/8, d1=0.641, d2=0.783 g=1.186
# >98, 3/8, d1=0.724, d2=0.641 g=0.931
# >98, 4/8, d1=0.679, d2=1.382 g=1.153
# >98, 5/8, d1=0.359, d2=0.561 g=1.631
# >98, 6/8, d1=0.589, d2=0.609 g=1.489
# >98, 7/8, d1=0.565, d2=0.676 g=1.333
# >98, 8/8, d1=0.692, d2=0.708 g=1.109
# >99, 1/8, d1=0.647, d2=0.828 g=1.310
# >99, 2/8, d1=0.779, d2=0.719 g=1.284
# >99, 3/8, d1=0.720, d2=0.615 g=0.911
# >99, 4/8, d1=0.589, d2=0.800 g=1.120
# >99, 5/8, d1=0.657, d2=0.907 g=1.266
# >99, 6/8, d1=1.091, d2=0.529 g=1.222
# >99, 7/8, d1=1.060, d2=0.756 g=1.120
# >99, 8/8, d1=0.765, d2=0.828 g=1.225
# >100, 1/8, d1=0.535, d2=0.694 g=1.127
# >100, 2/8, d1=0.546, d2=0.590 g=1.543
# >100, 3/8, d1=0.401, d2=0.407 g=1.575
# >100, 4/8, d1=0.882, d2=0.580 g=1.136
# >100, 5/8, d1=0.383, d2=0.536 g=1.361
# >100, 6/8, d1=0.552, d2=0.854 g=1.408
# >100, 7/8, d1=0.675, d2=0.363 g=1.370
# >100, 8/8, d1=0.279, d2=0.555 g=1.281
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 825us/step
# >Accuracy real: 0%, fake: 100%
# >101, 1/8, d1=0.656, d2=0.418 g=0.845
# >101, 2/8, d1=0.548, d2=0.643 g=0.906
# >101, 3/8, d1=0.534, d2=0.535 g=0.867
# >101, 4/8, d1=0.439, d2=0.647 g=1.021
# >101, 5/8, d1=0.456, d2=0.444 g=1.247
# >101, 6/8, d1=0.354, d2=0.465 g=0.841
# >101, 7/8, d1=0.874, d2=1.262 g=1.546
# >101, 8/8, d1=0.459, d2=0.563 g=1.625
# >102, 1/8, d1=0.925, d2=0.672 g=0.988
# >102, 2/8, d1=0.638, d2=0.900 g=1.224
# >102, 3/8, d1=0.293, d2=0.408 g=1.840
# >102, 4/8, d1=0.556, d2=0.307 g=1.477
# >102, 5/8, d1=1.258, d2=0.547 g=1.442
# >102, 6/8, d1=0.568, d2=0.505 g=1.188
# >102, 7/8, d1=0.774, d2=1.141 g=1.153
# >102, 8/8, d1=0.572, d2=0.466 g=1.820
# >103, 1/8, d1=0.410, d2=0.423 g=1.720
# >103, 2/8, d1=0.483, d2=0.346 g=1.515
# >103, 3/8, d1=0.283, d2=0.429 g=1.508
# >103, 4/8, d1=0.320, d2=0.545 g=1.381
# >103, 5/8, d1=0.605, d2=0.318 g=1.649
# >103, 6/8, d1=0.373, d2=0.480 g=1.412
# >103, 7/8, d1=0.412, d2=0.512 g=1.792
# >103, 8/8, d1=0.103, d2=0.383 g=1.958
# >104, 1/8, d1=0.359, d2=0.203 g=1.996
# >104, 2/8, d1=0.527, d2=0.465 g=1.637
# >104, 3/8, d1=0.193, d2=0.450 g=2.051
# >104, 4/8, d1=0.319, d2=0.254 g=2.331
# >104, 5/8, d1=0.525, d2=0.243 g=1.809
# >104, 6/8, d1=0.709, d2=0.269 g=1.161
# >104, 7/8, d1=0.161, d2=0.523 g=1.476
# >104, 8/8, d1=0.566, d2=0.588 g=2.340
# >105, 1/8, d1=0.512, d2=0.207 g=2.108
# >105, 2/8, d1=0.371, d2=0.775 g=1.936
# >105, 3/8, d1=0.185, d2=0.529 g=2.399
# >105, 4/8, d1=0.293, d2=0.151 g=2.209
# >105, 5/8, d1=0.776, d2=0.757 g=1.049
# >105, 6/8, d1=0.361, d2=0.200 g=1.069
# >105, 7/8, d1=0.230, d2=0.568 g=1.040
# >105, 8/8, d1=0.589, d2=1.776 g=2.546
# >106, 1/8, d1=0.707, d2=0.240 g=2.480
# >106, 2/8, d1=0.744, d2=0.635 g=1.676
# >106, 3/8, d1=0.281, d2=0.308 g=2.234
# >106, 4/8, d1=0.535, d2=0.461 g=2.102
# >106, 5/8, d1=0.347, d2=0.298 g=2.032
# >106, 6/8, d1=1.365, d2=0.738 g=2.036
# >106, 7/8, d1=0.585, d2=0.435 g=2.226
# >106, 8/8, d1=0.387, d2=0.253 g=1.682
# >107, 1/8, d1=0.173, d2=0.409 g=1.911
# >107, 2/8, d1=0.541, d2=0.360 g=1.849
# >107, 3/8, d1=0.187, d2=0.428 g=2.195
# >107, 4/8, d1=0.645, d2=0.678 g=2.132
# >107, 5/8, d1=0.322, d2=0.340 g=2.410
# >107, 6/8, d1=0.198, d2=0.217 g=2.357
# >107, 7/8, d1=0.286, d2=0.298 g=2.112
# >107, 8/8, d1=0.638, d2=0.330 g=1.497
# >108, 1/8, d1=0.093, d2=0.437 g=2.175
# >108, 2/8, d1=0.138, d2=0.210 g=2.657
# >108, 3/8, d1=0.334, d2=0.216 g=2.341
# >108, 4/8, d1=0.243, d2=0.306 g=2.154
# >108, 5/8, d1=0.132, d2=0.292 g=2.171
# >108, 6/8, d1=0.501, d2=0.463 g=2.106
# >108, 7/8, d1=0.119, d2=0.354 g=2.217
# >108, 8/8, d1=0.184, d2=0.137 g=1.726
# >109, 1/8, d1=0.087, d2=0.034 g=1.186
# >109, 2/8, d1=0.678, d2=0.834 g=0.795
# >109, 3/8, d1=0.256, d2=0.077 g=0.569
# >109, 4/8, d1=0.360, d2=1.912 g=1.778
# >109, 5/8, d1=0.701, d2=0.818 g=1.652
# >109, 6/8, d1=0.429, d2=0.353 g=1.796
# >109, 7/8, d1=0.867, d2=0.415 g=1.790
# >109, 8/8, d1=0.781, d2=0.420 g=1.525
# >110, 1/8, d1=0.997, d2=0.657 g=1.152
# >110, 2/8, d1=0.426, d2=0.443 g=1.988
# >110, 3/8, d1=1.141, d2=0.598 g=1.747
# >110, 4/8, d1=0.622, d2=1.001 g=1.934
# >110, 5/8, d1=1.004, d2=0.453 g=1.368
# >110, 6/8, d1=0.365, d2=0.515 g=1.924
# >110, 7/8, d1=0.386, d2=0.328 g=2.433
# >110, 8/8, d1=0.702, d2=0.262 g=1.709
# >111, 1/8, d1=1.694, d2=0.577 g=1.024
# >111, 2/8, d1=0.351, d2=1.109 g=1.588
# >111, 3/8, d1=0.450, d2=0.283 g=1.733
# >111, 4/8, d1=0.543, d2=0.408 g=2.163
# >111, 5/8, d1=0.320, d2=0.289 g=2.663
# >111, 6/8, d1=0.294, d2=0.295 g=2.351
# >111, 7/8, d1=0.352, d2=0.299 g=1.992
# >111, 8/8, d1=0.297, d2=0.612 g=1.678
# >112, 1/8, d1=0.301, d2=0.274 g=1.607
# >112, 2/8, d1=0.461, d2=0.599 g=1.595
# >112, 3/8, d1=0.433, d2=0.235 g=1.333
# >112, 4/8, d1=0.284, d2=0.495 g=1.530
# >112, 5/8, d1=0.604, d2=0.673 g=0.667
# >112, 6/8, d1=0.383, d2=1.298 g=1.336
# >112, 7/8, d1=0.919, d2=1.562 g=1.248
# >112, 8/8, d1=0.904, d2=0.391 g=1.204
# >113, 1/8, d1=1.241, d2=1.316 g=1.511
# >113, 2/8, d1=0.630, d2=0.675 g=1.772
# >113, 3/8, d1=0.880, d2=0.526 g=1.688
# >113, 4/8, d1=0.315, d2=0.567 g=1.499
# >113, 5/8, d1=0.259, d2=0.465 g=1.959
# >113, 6/8, d1=0.524, d2=0.236 g=2.525
# >113, 7/8, d1=0.228, d2=0.282 g=2.057
# >113, 8/8, d1=0.280, d2=0.319 g=2.001
# >114, 1/8, d1=0.303, d2=0.531 g=1.756
# >114, 2/8, d1=0.366, d2=0.313 g=1.675
# >114, 3/8, d1=0.343, d2=0.464 g=1.309
# >114, 4/8, d1=0.771, d2=0.897 g=1.322
# >114, 5/8, d1=0.276, d2=0.290 g=1.772
# >114, 6/8, d1=0.405, d2=0.397 g=0.843
# >114, 7/8, d1=0.490, d2=1.267 g=1.303
# >114, 8/8, d1=0.619, d2=0.395 g=1.575
# >115, 1/8, d1=0.415, d2=0.664 g=1.510
# >115, 2/8, d1=1.265, d2=0.602 g=1.507
# >115, 3/8, d1=0.450, d2=0.398 g=1.385
# >115, 4/8, d1=0.650, d2=0.636 g=1.465
# >115, 5/8, d1=0.974, d2=0.818 g=1.509
# >115, 6/8, d1=0.701, d2=0.530 g=1.628
# >115, 7/8, d1=0.381, d2=0.421 g=1.739
# >115, 8/8, d1=0.586, d2=0.577 g=1.477
# >116, 1/8, d1=1.535, d2=1.167 g=0.764
# >116, 2/8, d1=0.315, d2=0.438 g=0.877
# >116, 3/8, d1=0.660, d2=1.083 g=0.911
# >116, 4/8, d1=0.947, d2=0.170 g=0.905
# >116, 5/8, d1=0.450, d2=0.560 g=0.957
# >116, 6/8, d1=0.642, d2=0.876 g=1.069
# >116, 7/8, d1=0.672, d2=0.554 g=1.183
# >116, 8/8, d1=0.567, d2=0.305 g=0.976
# >117, 1/8, d1=0.665, d2=0.488 g=0.964
# >117, 2/8, d1=0.571, d2=0.435 g=0.888
# >117, 3/8, d1=0.572, d2=0.915 g=1.127
# >117, 4/8, d1=0.581, d2=0.467 g=1.058
# >117, 5/8, d1=0.913, d2=0.393 g=0.564
# >117, 6/8, d1=0.592, d2=1.303 g=0.983
# >117, 7/8, d1=0.602, d2=0.656 g=1.076
# >117, 8/8, d1=0.771, d2=0.709 g=0.948
# >118, 1/8, d1=0.546, d2=0.418 g=1.177
# >118, 2/8, d1=0.651, d2=0.755 g=1.404
# >118, 3/8, d1=0.573, d2=0.526 g=1.096
# >118, 4/8, d1=0.631, d2=0.543 g=1.320
# >118, 5/8, d1=0.648, d2=0.728 g=1.239
# >118, 6/8, d1=0.932, d2=0.725 g=1.650
# >118, 7/8, d1=1.706, d2=0.507 g=1.590
# >118, 8/8, d1=0.513, d2=0.338 g=1.389
# >119, 1/8, d1=0.527, d2=0.568 g=1.635
# >119, 2/8, d1=0.477, d2=0.565 g=2.020
# >119, 3/8, d1=0.230, d2=0.363 g=2.590
# >119, 4/8, d1=0.479, d2=0.311 g=1.938
# >119, 5/8, d1=0.265, d2=0.503 g=1.606
# >119, 6/8, d1=0.378, d2=0.445 g=1.450
# >119, 7/8, d1=0.782, d2=0.363 g=0.947
# >119, 8/8, d1=0.690, d2=0.643 g=0.554
# >120, 1/8, d1=0.557, d2=0.624 g=0.588
# >120, 2/8, d1=1.532, d2=0.733 g=0.555
# >120, 3/8, d1=0.700, d2=1.433 g=0.948
# >120, 4/8, d1=0.501, d2=0.839 g=1.408
# >120, 5/8, d1=0.750, d2=0.489 g=2.372
# >120, 6/8, d1=0.445, d2=0.227 g=1.857
# >120, 7/8, d1=0.483, d2=0.498 g=1.379
# >120, 8/8, d1=0.688, d2=0.759 g=1.138
# >121, 1/8, d1=0.355, d2=0.629 g=1.807
# >121, 2/8, d1=0.258, d2=0.312 g=1.642
# >121, 3/8, d1=0.482, d2=0.303 g=1.340
# >121, 4/8, d1=0.713, d2=0.411 g=0.801
# >121, 5/8, d1=0.233, d2=0.577 g=0.697
# >121, 6/8, d1=0.587, d2=0.847 g=1.004
# >121, 7/8, d1=1.513, d2=0.999 g=0.573
# >121, 8/8, d1=0.562, d2=0.801 g=1.097
# >122, 1/8, d1=0.907, d2=0.798 g=0.836
# >122, 2/8, d1=1.140, d2=0.589 g=0.830
# >122, 3/8, d1=0.367, d2=1.090 g=1.472
# >122, 4/8, d1=1.210, d2=0.556 g=1.622
# >122, 5/8, d1=1.293, d2=0.369 g=1.094
# >122, 6/8, d1=0.691, d2=0.887 g=0.885
# >122, 7/8, d1=0.578, d2=0.920 g=1.504
# >122, 8/8, d1=0.949, d2=0.480 g=1.612
# >123, 1/8, d1=0.949, d2=0.594 g=1.767
# >123, 2/8, d1=0.715, d2=0.649 g=1.805
# >123, 3/8, d1=0.817, d2=0.605 g=1.393
# >123, 4/8, d1=0.335, d2=0.567 g=1.652
# >123, 5/8, d1=0.912, d2=0.495 g=1.725
# >123, 6/8, d1=0.915, d2=0.583 g=1.390
# >123, 7/8, d1=0.797, d2=0.740 g=1.135
# >123, 8/8, d1=1.224, d2=0.841 g=1.436
# >124, 1/8, d1=0.577, d2=0.347 g=1.433
# >124, 2/8, d1=0.930, d2=0.373 g=1.422
# >124, 3/8, d1=0.640, d2=0.766 g=1.326
# >124, 4/8, d1=0.749, d2=0.612 g=1.185
# >124, 5/8, d1=0.442, d2=0.487 g=1.308
# >124, 6/8, d1=0.422, d2=0.729 g=1.371
# >124, 7/8, d1=0.789, d2=0.417 g=1.556
# >124, 8/8, d1=0.533, d2=0.909 g=1.144
# >125, 1/8, d1=0.508, d2=0.589 g=1.646
# >125, 2/8, d1=0.643, d2=0.386 g=1.108
# >125, 3/8, d1=0.384, d2=0.853 g=1.071
# >125, 4/8, d1=0.579, d2=0.365 g=0.912
# >125, 5/8, d1=0.381, d2=0.674 g=1.452
# >125, 6/8, d1=0.920, d2=0.447 g=1.162
# >125, 7/8, d1=0.504, d2=0.589 g=1.695
# >125, 8/8, d1=0.500, d2=0.348 g=1.647
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 806us/step
# >Accuracy real: 18%, fake: 100%
# >126, 1/8, d1=0.471, d2=0.625 g=1.520
# >126, 2/8, d1=0.668, d2=0.428 g=1.122
# >126, 3/8, d1=0.380, d2=0.458 g=0.721
# >126, 4/8, d1=0.683, d2=0.485 g=0.701
# >126, 5/8, d1=0.459, d2=0.416 g=0.786
# >126, 6/8, d1=0.363, d2=0.358 g=0.880
# >126, 7/8, d1=0.418, d2=0.781 g=1.740
# >126, 8/8, d1=0.503, d2=0.266 g=2.202
# >127, 1/8, d1=0.326, d2=0.183 g=2.165
# >127, 2/8, d1=0.114, d2=0.270 g=1.827
# >127, 3/8, d1=0.579, d2=0.515 g=1.608
# >127, 4/8, d1=0.202, d2=0.409 g=2.829
# >127, 5/8, d1=0.429, d2=0.158 g=2.610
# >127, 6/8, d1=0.725, d2=0.338 g=2.158
# >127, 7/8, d1=0.126, d2=0.234 g=2.178
# >127, 8/8, d1=0.231, d2=0.465 g=2.405
# >128, 1/8, d1=0.251, d2=0.270 g=2.796
# >128, 2/8, d1=0.358, d2=0.198 g=2.729
# >128, 3/8, d1=0.090, d2=0.121 g=2.695
# >128, 4/8, d1=0.284, d2=0.307 g=2.450
# >128, 5/8, d1=0.171, d2=0.384 g=2.972
# >128, 6/8, d1=0.223, d2=0.104 g=3.261
# >128, 7/8, d1=0.220, d2=0.161 g=2.706
# >128, 8/8, d1=0.262, d2=0.185 g=2.760
# >129, 1/8, d1=0.214, d2=0.300 g=2.625
# >129, 2/8, d1=0.111, d2=0.212 g=2.994
# >129, 3/8, d1=0.244, d2=0.193 g=3.171
# >129, 4/8, d1=0.125, d2=0.112 g=3.222
# >129, 5/8, d1=0.092, d2=0.191 g=2.983
# >129, 6/8, d1=0.309, d2=0.337 g=2.964
# >129, 7/8, d1=0.178, d2=0.105 g=3.431
# >129, 8/8, d1=0.142, d2=0.113 g=3.361
# >130, 1/8, d1=2.891, d2=0.422 g=2.275
# >130, 2/8, d1=0.150, d2=0.314 g=2.908
# >130, 3/8, d1=0.037, d2=0.195 g=2.995
# >130, 4/8, d1=0.058, d2=0.136 g=3.188
# >130, 5/8, d1=0.099, d2=0.120 g=3.303
# >130, 6/8, d1=0.569, d2=0.154 g=3.039
# >130, 7/8, d1=0.071, d2=0.212 g=3.004
# >130, 8/8, d1=0.340, d2=0.136 g=2.874
# >131, 1/8, d1=0.026, d2=0.280 g=3.245
# >131, 2/8, d1=0.087, d2=0.141 g=3.302
# >131, 3/8, d1=0.254, d2=0.162 g=3.094
# >131, 4/8, d1=0.173, d2=0.244 g=3.300
# >131, 5/8, d1=0.095, d2=0.111 g=3.247
# >131, 6/8, d1=0.060, d2=0.118 g=3.394
# >131, 7/8, d1=0.062, d2=0.099 g=3.276
# >131, 8/8, d1=0.076, d2=0.078 g=3.040
# >132, 1/8, d1=0.046, d2=0.168 g=3.209
# >132, 2/8, d1=0.712, d2=0.161 g=2.862
# >132, 3/8, d1=0.057, d2=0.203 g=3.101
# >132, 4/8, d1=0.176, d2=0.145 g=3.450
# >132, 5/8, d1=0.044, d2=0.128 g=3.775
# >132, 6/8, d1=0.125, d2=0.093 g=3.368
# >132, 7/8, d1=0.431, d2=0.182 g=3.580
# >132, 8/8, d1=0.019, d2=0.122 g=3.602
# >133, 1/8, d1=0.166, d2=0.133 g=3.626
# >133, 2/8, d1=0.266, d2=0.090 g=3.544
# >133, 3/8, d1=0.054, d2=0.073 g=3.475
# >133, 4/8, d1=0.028, d2=0.132 g=3.468
# >133, 5/8, d1=0.083, d2=0.099 g=3.617
# ...
# >449, 8/8, d1=0.606, d2=0.382 g=2.545
# >450, 1/8, d1=0.157, d2=0.313 g=2.470
# >450, 2/8, d1=0.176, d2=0.318 g=2.490
# >450, 3/8, d1=0.383, d2=0.076 g=2.350
# >450, 4/8, d1=0.340, d2=0.500 g=1.806
# >450, 5/8, d1=0.198, d2=0.175 g=1.699
# >450, 6/8, d1=0.250, d2=0.255 g=1.893
# >450, 7/8, d1=0.254, d2=0.428 g=1.986
# >450, 8/8, d1=0.061, d2=0.264 g=2.793
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 858us/step
# >Accuracy real: 0%, fake: 100%
# >451, 1/8, d1=0.491, d2=0.139 g=2.063
# >451, 2/8, d1=0.280, d2=0.463 g=2.040
# >451, 3/8, d1=0.442, d2=0.115 g=1.980
# >451, 4/8, d1=0.364, d2=0.551 g=2.015
# >451, 5/8, d1=0.051, d2=0.622 g=2.699
# >451, 6/8, d1=1.154, d2=0.347 g=2.079
# >451, 7/8, d1=0.358, d2=0.178 g=2.248
# >451, 8/8, d1=0.387, d2=0.794 g=2.571
# >452, 1/8, d1=0.488, d2=0.140 g=1.985
# >452, 2/8, d1=0.630, d2=0.277 g=1.739
# >452, 3/8, d1=0.207, d2=0.139 g=1.755
# >452, 4/8, d1=0.317, d2=0.621 g=1.479
# >452, 5/8, d1=0.334, d2=0.278 g=2.290
# >452, 6/8, d1=0.461, d2=0.272 g=2.514
# >452, 7/8, d1=0.465, d2=0.194 g=1.634
# >452, 8/8, d1=0.114, d2=0.252 g=2.104
# >453, 1/8, d1=0.054, d2=0.205 g=2.523
# >453, 2/8, d1=0.443, d2=0.364 g=2.133
# >453, 3/8, d1=0.443, d2=0.192 g=1.784
# >453, 4/8, d1=0.341, d2=0.197 g=1.727
# >453, 5/8, d1=0.114, d2=0.378 g=1.970
# >453, 6/8, d1=0.118, d2=0.167 g=2.998
# >453, 7/8, d1=0.366, d2=0.194 g=2.323
# >453, 8/8, d1=0.232, d2=0.267 g=2.102
# >454, 1/8, d1=0.250, d2=0.210 g=2.056
# >454, 2/8, d1=0.381, d2=0.723 g=1.947
# >454, 3/8, d1=0.140, d2=0.496 g=2.915
# >454, 4/8, d1=0.248, d2=0.187 g=2.854
# >454, 5/8, d1=0.535, d2=0.171 g=3.183
# >454, 6/8, d1=0.640, d2=0.243 g=2.367
# >454, 7/8, d1=0.239, d2=0.330 g=2.271
# >454, 8/8, d1=0.112, d2=0.177 g=3.027
# >455, 1/8, d1=0.488, d2=0.042 g=1.967
# >455, 2/8, d1=0.340, d2=0.320 g=1.872
# >455, 3/8, d1=0.618, d2=0.267 g=2.228
# >455, 4/8, d1=0.219, d2=0.048 g=2.289
# >455, 5/8, d1=0.101, d2=0.402 g=2.821
# >455, 6/8, d1=0.435, d2=0.253 g=2.477
# >455, 7/8, d1=0.698, d2=0.417 g=2.331
# >455, 8/8, d1=0.232, d2=0.269 g=2.468
# >456, 1/8, d1=0.816, d2=0.177 g=2.082
# >456, 2/8, d1=0.356, d2=0.195 g=1.923
# >456, 3/8, d1=1.015, d2=0.761 g=1.372
# >456, 4/8, d1=0.012, d2=0.346 g=2.467
# >456, 5/8, d1=0.260, d2=0.096 g=2.351
# >456, 6/8, d1=0.285, d2=0.297 g=1.836
# >456, 7/8, d1=0.036, d2=0.457 g=2.665
# >456, 8/8, d1=0.092, d2=0.085 g=2.878
# >457, 1/8, d1=0.077, d2=0.094 g=2.984
# >457, 2/8, d1=0.712, d2=0.197 g=1.589
# >457, 3/8, d1=0.069, d2=0.119 g=1.327
# >457, 4/8, d1=1.468, d2=0.677 g=1.364
# >457, 5/8, d1=0.637, d2=0.663 g=1.101
# >457, 6/8, d1=0.130, d2=0.318 g=2.227
# >457, 7/8, d1=0.159, d2=0.245 g=1.608
# >457, 8/8, d1=0.129, d2=0.135 g=2.386
# >458, 1/8, d1=0.325, d2=0.127 g=1.879
# >458, 2/8, d1=0.406, d2=0.418 g=1.946
# >458, 3/8, d1=1.840, d2=0.469 g=1.946
# >458, 4/8, d1=0.688, d2=0.790 g=2.399
# >458, 5/8, d1=0.223, d2=0.104 g=2.667
# >458, 6/8, d1=0.205, d2=0.411 g=2.567
# >458, 7/8, d1=0.131, d2=0.180 g=2.772
# >458, 8/8, d1=0.784, d2=0.252 g=2.425
# >459, 1/8, d1=0.192, d2=0.343 g=2.383
# >459, 2/8, d1=0.278, d2=0.167 g=2.394
# >459, 3/8, d1=0.100, d2=0.089 g=2.544
# >459, 4/8, d1=1.305, d2=0.597 g=1.012
# >459, 5/8, d1=0.127, d2=1.181 g=3.082
# >459, 6/8, d1=0.116, d2=0.238 g=3.452
# >459, 7/8, d1=0.109, d2=0.071 g=3.041
# >459, 8/8, d1=0.501, d2=0.130 g=2.976
# >460, 1/8, d1=0.035, d2=0.123 g=2.260
# >460, 2/8, d1=0.168, d2=0.335 g=2.047
# >460, 3/8, d1=0.109, d2=0.398 g=2.621
# >460, 4/8, d1=0.328, d2=0.165 g=2.815
# >460, 5/8, d1=0.382, d2=0.617 g=3.025
# >460, 6/8, d1=1.660, d2=0.255 g=2.417
# >460, 7/8, d1=0.212, d2=0.299 g=1.716
# >460, 8/8, d1=0.307, d2=0.773 g=2.385
# >461, 1/8, d1=0.300, d2=0.239 g=2.555
# >461, 2/8, d1=0.642, d2=0.580 g=2.579
# >461, 3/8, d1=0.661, d2=0.248 g=2.325
# >461, 4/8, d1=0.752, d2=0.391 g=1.675
# >461, 5/8, d1=0.377, d2=0.606 g=2.582
# >461, 6/8, d1=0.274, d2=0.205 g=3.301
# >461, 7/8, d1=1.012, d2=0.220 g=2.151
# >461, 8/8, d1=0.111, d2=0.333 g=2.574
# >462, 1/8, d1=1.202, d2=0.348 g=1.908
# >462, 2/8, d1=0.256, d2=0.421 g=1.391
# >462, 3/8, d1=0.429, d2=0.447 g=1.462
# >462, 4/8, d1=0.066, d2=0.137 g=2.919
# >462, 5/8, d1=0.682, d2=0.749 g=3.770
# >462, 6/8, d1=2.032, d2=0.599 g=3.301
# >462, 7/8, d1=0.522, d2=0.651 g=2.596
# >462, 8/8, d1=0.224, d2=0.113 g=2.413
# >463, 1/8, d1=0.484, d2=0.367 g=1.906
# >463, 2/8, d1=0.082, d2=0.397 g=2.400
# >463, 3/8, d1=0.341, d2=0.183 g=2.457
# >463, 4/8, d1=0.770, d2=0.180 g=1.527
# >463, 5/8, d1=0.566, d2=0.819 g=1.759
# >463, 6/8, d1=0.327, d2=0.309 g=1.993
# >463, 7/8, d1=0.291, d2=0.188 g=1.884
# >463, 8/8, d1=0.176, d2=0.278 g=2.328
# >464, 1/8, d1=0.184, d2=0.236 g=2.355
# >464, 2/8, d1=0.177, d2=0.127 g=1.893
# >464, 3/8, d1=0.502, d2=0.329 g=1.654
# >464, 4/8, d1=0.394, d2=0.546 g=2.225
# >464, 5/8, d1=0.077, d2=0.172 g=2.240
# >464, 6/8, d1=0.421, d2=0.227 g=1.616
# >464, 7/8, d1=0.068, d2=0.242 g=1.926
# >464, 8/8, d1=1.040, d2=0.861 g=2.538
# >465, 1/8, d1=0.068, d2=0.380 g=2.901
# >465, 2/8, d1=1.402, d2=0.584 g=2.683
# >465, 3/8, d1=0.553, d2=0.221 g=2.014
# >465, 4/8, d1=0.174, d2=0.433 g=2.404
# >465, 5/8, d1=0.423, d2=0.223 g=2.261
# >465, 6/8, d1=0.256, d2=0.159 g=2.103
# >465, 7/8, d1=0.079, d2=0.056 g=1.300
# >465, 8/8, d1=0.403, d2=0.852 g=2.036
# >466, 1/8, d1=0.089, d2=0.283 g=3.159
# >466, 2/8, d1=0.253, d2=0.066 g=2.975
# >466, 3/8, d1=0.448, d2=0.179 g=2.098
# >466, 4/8, d1=0.866, d2=0.418 g=1.922
# >466, 5/8, d1=0.240, d2=0.437 g=1.984
# >466, 6/8, d1=0.087, d2=0.062 g=2.385
# >466, 7/8, d1=0.203, d2=0.134 g=2.504
# >466, 8/8, d1=0.219, d2=0.185 g=1.816
# >467, 1/8, d1=0.276, d2=0.488 g=2.681
# >467, 2/8, d1=1.331, d2=0.726 g=2.028
# >467, 3/8, d1=0.041, d2=0.236 g=2.012
# >467, 4/8, d1=0.377, d2=0.327 g=1.868
# >467, 5/8, d1=0.321, d2=0.178 g=1.520
# >467, 6/8, d1=0.235, d2=0.245 g=1.234
# >467, 7/8, d1=0.165, d2=0.194 g=1.434
# >467, 8/8, d1=0.096, d2=0.684 g=2.636
# >468, 1/8, d1=0.183, d2=0.062 g=2.125
# >468, 2/8, d1=0.584, d2=0.343 g=1.879
# >468, 3/8, d1=0.279, d2=0.372 g=1.635
# >468, 4/8, d1=0.748, d2=0.297 g=1.192
# >468, 5/8, d1=0.287, d2=0.355 g=1.609
# >468, 6/8, d1=0.435, d2=0.733 g=1.956
# >468, 7/8, d1=0.210, d2=0.158 g=2.170
# >468, 8/8, d1=0.755, d2=0.319 g=2.047
# >469, 1/8, d1=0.300, d2=0.277 g=1.322
# >469, 2/8, d1=0.245, d2=0.379 g=3.012
# >469, 3/8, d1=0.385, d2=0.317 g=2.540
# >469, 4/8, d1=0.491, d2=0.427 g=2.156
# >469, 5/8, d1=0.046, d2=0.385 g=3.118
# >469, 6/8, d1=0.321, d2=0.236 g=2.529
# >469, 7/8, d1=0.522, d2=0.115 g=1.842
# >469, 8/8, d1=0.304, d2=0.591 g=1.440
# >470, 1/8, d1=0.146, d2=0.155 g=2.276
# >470, 2/8, d1=0.792, d2=0.609 g=2.420
# >470, 3/8, d1=0.339, d2=0.485 g=2.566
# >470, 4/8, d1=0.255, d2=0.137 g=2.477
# >470, 5/8, d1=0.405, d2=0.298 g=1.871
# >470, 6/8, d1=0.137, d2=0.184 g=1.606
# >470, 7/8, d1=0.327, d2=0.311 g=1.548
# >470, 8/8, d1=0.711, d2=0.852 g=1.996
# >471, 1/8, d1=0.284, d2=0.312 g=2.832
# >471, 2/8, d1=0.205, d2=0.448 g=3.205
# >471, 3/8, d1=0.435, d2=0.155 g=2.970
# >471, 4/8, d1=0.324, d2=0.145 g=2.028
# >471, 5/8, d1=0.405, d2=0.554 g=1.931
# >471, 6/8, d1=0.833, d2=0.423 g=2.105
# >471, 7/8, d1=0.255, d2=0.707 g=2.523
# >471, 8/8, d1=0.554, d2=0.478 g=2.928
# >472, 1/8, d1=0.421, d2=0.250 g=2.231
# >472, 2/8, d1=0.835, d2=0.319 g=1.968
# >472, 3/8, d1=0.327, d2=0.341 g=2.091
# >472, 4/8, d1=0.232, d2=0.616 g=2.647
# >472, 5/8, d1=0.239, d2=0.059 g=3.009
# >472, 6/8, d1=0.797, d2=0.491 g=2.144
# >472, 7/8, d1=0.289, d2=0.267 g=2.032
# >472, 8/8, d1=0.382, d2=0.123 g=2.069
# >473, 1/8, d1=0.310, d2=0.465 g=2.366
# >473, 2/8, d1=0.081, d2=0.128 g=3.163
# >473, 3/8, d1=0.443, d2=0.272 g=2.092
# >473, 4/8, d1=0.744, d2=0.168 g=2.196
# >473, 5/8, d1=0.235, d2=0.200 g=2.676
# >473, 6/8, d1=0.269, d2=0.232 g=2.042
# >473, 7/8, d1=0.288, d2=0.406 g=2.552
# >473, 8/8, d1=0.208, d2=0.463 g=3.072
# >474, 1/8, d1=0.260, d2=0.116 g=3.165
# >474, 2/8, d1=0.647, d2=0.307 g=3.173
# >474, 3/8, d1=0.526, d2=0.247 g=1.979
# >474, 4/8, d1=0.138, d2=0.462 g=2.559
# >474, 5/8, d1=0.090, d2=0.212 g=2.630
# >474, 6/8, d1=0.505, d2=0.216 g=2.291
# >474, 7/8, d1=0.963, d2=0.270 g=2.355
# >474, 8/8, d1=0.143, d2=0.372 g=2.267
# >475, 1/8, d1=0.532, d2=0.494 g=3.174
# >475, 2/8, d1=0.090, d2=0.407 g=3.204
# >475, 3/8, d1=0.270, d2=0.133 g=2.769
# >475, 4/8, d1=0.738, d2=0.237 g=2.119
# >475, 5/8, d1=0.098, d2=0.191 g=1.714
# >475, 6/8, d1=0.251, d2=0.995 g=2.498
# >475, 7/8, d1=0.075, d2=0.237 g=3.576
# >475, 8/8, d1=1.153, d2=0.274 g=2.853
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 868us/step
# >Accuracy real: 2%, fake: 100%
# >476, 1/8, d1=0.219, d2=0.355 g=2.805
# >476, 2/8, d1=0.635, d2=0.128 g=1.736
# >476, 3/8, d1=0.215, d2=1.107 g=2.429
# >476, 4/8, d1=0.063, d2=0.279 g=3.644
# >476, 5/8, d1=0.818, d2=0.292 g=2.879
# >476, 6/8, d1=0.460, d2=0.570 g=2.584
# >476, 7/8, d1=0.395, d2=0.348 g=2.130
# >476, 8/8, d1=0.111, d2=0.251 g=2.594
# >477, 1/8, d1=0.310, d2=0.271 g=2.871
# >477, 2/8, d1=0.760, d2=0.295 g=1.434
# >477, 3/8, d1=0.141, d2=0.726 g=2.582
# >477, 4/8, d1=0.734, d2=0.239 g=2.921
# >477, 5/8, d1=0.157, d2=0.415 g=2.243
# >477, 6/8, d1=0.427, d2=0.213 g=2.124
# >477, 7/8, d1=0.391, d2=0.253 g=2.463
# >477, 8/8, d1=0.522, d2=0.498 g=2.365
# >478, 1/8, d1=0.446, d2=0.505 g=2.098
# >478, 2/8, d1=1.006, d2=1.146 g=2.717
# >478, 3/8, d1=0.443, d2=0.239 g=2.815
# >478, 4/8, d1=0.443, d2=0.217 g=2.763
# >478, 5/8, d1=0.409, d2=0.106 g=2.364
# >478, 6/8, d1=0.190, d2=0.183 g=2.451
# >478, 7/8, d1=0.945, d2=0.214 g=1.602
# >478, 8/8, d1=0.135, d2=1.100 g=2.035
# >479, 1/8, d1=0.274, d2=0.248 g=3.298
# >479, 2/8, d1=0.481, d2=0.174 g=2.452
# >479, 3/8, d1=0.480, d2=0.444 g=2.636
# >479, 4/8, d1=0.431, d2=0.224 g=2.020
# >479, 5/8, d1=0.058, d2=0.237 g=2.350
# >479, 6/8, d1=0.230, d2=0.307 g=2.487
# >479, 7/8, d1=0.408, d2=0.260 g=2.279
# >479, 8/8, d1=0.448, d2=0.383 g=2.638
# >480, 1/8, d1=0.189, d2=0.546 g=3.056
# >480, 2/8, d1=0.175, d2=0.199 g=2.600
# >480, 3/8, d1=0.239, d2=0.098 g=2.439
# >480, 4/8, d1=0.187, d2=0.235 g=2.658
# >480, 5/8, d1=0.260, d2=0.051 g=2.289
# >480, 6/8, d1=0.171, d2=0.423 g=2.850
# >480, 7/8, d1=0.433, d2=0.071 g=1.967
# >480, 8/8, d1=0.409, d2=0.387 g=1.401
# >481, 1/8, d1=0.109, d2=0.533 g=2.510
# >481, 2/8, d1=0.242, d2=0.444 g=3.280
# >481, 3/8, d1=0.268, d2=0.128 g=2.756
# >481, 4/8, d1=0.761, d2=0.214 g=2.128
# >481, 5/8, d1=0.604, d2=0.333 g=1.583
# >481, 6/8, d1=0.305, d2=0.280 g=1.577
# >481, 7/8, d1=0.380, d2=0.174 g=1.228
# >481, 8/8, d1=0.086, d2=0.893 g=2.894
# >482, 1/8, d1=0.501, d2=0.163 g=3.158
# >482, 2/8, d1=0.588, d2=0.107 g=1.735
# >482, 3/8, d1=0.038, d2=0.484 g=1.618
# >482, 4/8, d1=0.220, d2=0.262 g=2.474
# >482, 5/8, d1=0.477, d2=0.348 g=1.887
# >482, 6/8, d1=0.437, d2=0.327 g=3.004
# >482, 7/8, d1=0.098, d2=0.094 g=1.941
# >482, 8/8, d1=0.162, d2=0.657 g=1.907
# >483, 1/8, d1=0.257, d2=0.230 g=2.161
# >483, 2/8, d1=0.222, d2=0.285 g=3.469
# >483, 3/8, d1=0.380, d2=0.254 g=2.175
# >483, 4/8, d1=0.848, d2=0.391 g=2.071
# >483, 5/8, d1=1.295, d2=0.570 g=1.567
# >483, 6/8, d1=0.125, d2=0.425 g=2.060
# >483, 7/8, d1=0.459, d2=0.248 g=2.416
# >483, 8/8, d1=1.093, d2=0.144 g=1.280
# >484, 1/8, d1=0.233, d2=0.416 g=1.664
# >484, 2/8, d1=0.341, d2=0.607 g=2.080
# >484, 3/8, d1=0.466, d2=0.093 g=2.575
# >484, 4/8, d1=0.207, d2=0.095 g=1.673
# >484, 5/8, d1=0.568, d2=0.482 g=1.029
# >484, 6/8, d1=0.527, d2=0.298 g=2.062
# >484, 7/8, d1=0.245, d2=0.285 g=2.619
# >484, 8/8, d1=0.310, d2=0.220 g=2.647
# >485, 1/8, d1=0.106, d2=0.275 g=3.070
# >485, 2/8, d1=0.167, d2=0.078 g=2.224
# >485, 3/8, d1=0.429, d2=0.486 g=2.126
# >485, 4/8, d1=0.234, d2=0.269 g=2.423
# >485, 5/8, d1=0.328, d2=0.311 g=2.206
# >485, 6/8, d1=0.091, d2=0.150 g=2.730
# >485, 7/8, d1=0.443, d2=0.264 g=2.361
# >485, 8/8, d1=0.035, d2=0.214 g=2.297
# >486, 1/8, d1=0.136, d2=0.316 g=2.636
# >486, 2/8, d1=0.319, d2=0.167 g=1.886
# >486, 3/8, d1=0.395, d2=0.405 g=2.256
# >486, 4/8, d1=0.345, d2=0.320 g=3.139
# >486, 5/8, d1=0.452, d2=0.195 g=2.411
# >486, 6/8, d1=0.303, d2=0.309 g=2.511
# >486, 7/8, d1=0.607, d2=0.287 g=2.010
# >486, 8/8, d1=0.560, d2=0.585 g=1.588
# >487, 1/8, d1=0.161, d2=0.510 g=2.904
# >487, 2/8, d1=0.713, d2=0.255 g=2.361
# >487, 3/8, d1=0.286, d2=0.225 g=2.260
# >487, 4/8, d1=0.277, d2=0.260 g=1.316
# >487, 5/8, d1=0.150, d2=0.324 g=2.543
# >487, 6/8, d1=0.403, d2=0.428 g=1.907
# >487, 7/8, d1=0.147, d2=0.449 g=2.128
# >487, 8/8, d1=0.596, d2=0.380 g=2.313
# >488, 1/8, d1=0.720, d2=0.516 g=2.122
# >488, 2/8, d1=0.542, d2=0.933 g=3.938
# >488, 3/8, d1=0.400, d2=0.083 g=3.766
# >488, 4/8, d1=0.757, d2=0.169 g=2.872
# >488, 5/8, d1=1.042, d2=0.580 g=2.060
# >488, 6/8, d1=0.112, d2=0.328 g=2.562
# >488, 7/8, d1=0.188, d2=0.243 g=2.685
# >488, 8/8, d1=0.102, d2=0.102 g=2.601
# >489, 1/8, d1=0.617, d2=0.242 g=1.680
# >489, 2/8, d1=0.246, d2=0.737 g=2.823
# >489, 3/8, d1=0.256, d2=0.253 g=3.289
# >489, 4/8, d1=0.285, d2=0.331 g=3.303
# >489, 5/8, d1=0.139, d2=0.116 g=2.481
# >489, 6/8, d1=0.184, d2=0.080 g=2.230
# >489, 7/8, d1=0.174, d2=0.522 g=2.672
# >489, 8/8, d1=0.241, d2=0.080 g=2.194
# >490, 1/8, d1=0.561, d2=0.298 g=1.860
# >490, 2/8, d1=0.616, d2=0.861 g=2.787
# >490, 3/8, d1=0.376, d2=0.520 g=2.619
# >490, 4/8, d1=0.665, d2=0.154 g=2.469
# >490, 5/8, d1=0.407, d2=0.339 g=2.388
# >490, 6/8, d1=0.702, d2=0.291 g=1.885
# >490, 7/8, d1=0.118, d2=0.636 g=1.968
# >490, 8/8, d1=0.352, d2=0.314 g=2.335
# >491, 1/8, d1=0.445, d2=0.205 g=2.402
# >491, 2/8, d1=0.365, d2=0.213 g=1.983
# >491, 3/8, d1=0.375, d2=0.589 g=1.976
# >491, 4/8, d1=0.507, d2=0.096 g=1.328
# >491, 5/8, d1=0.182, d2=0.507 g=1.694
# >491, 6/8, d1=0.277, d2=0.271 g=2.204
# >491, 7/8, d1=0.722, d2=0.551 g=2.641
# >491, 8/8, d1=0.176, d2=0.249 g=2.479
# >492, 1/8, d1=0.278, d2=0.262 g=2.029
# >492, 2/8, d1=0.808, d2=1.042 g=3.135
# >492, 3/8, d1=0.378, d2=0.074 g=3.191
# >492, 4/8, d1=0.362, d2=0.197 g=2.578
# >492, 5/8, d1=0.109, d2=0.078 g=2.048
# >492, 6/8, d1=0.597, d2=0.208 g=1.404
# >492, 7/8, d1=0.497, d2=1.449 g=2.971
# >492, 8/8, d1=0.729, d2=0.410 g=3.076
# >493, 1/8, d1=0.162, d2=0.117 g=3.133
# >493, 2/8, d1=0.118, d2=0.228 g=2.183
# >493, 3/8, d1=0.352, d2=0.297 g=2.685
# >493, 4/8, d1=0.110, d2=0.255 g=2.092
# >493, 5/8, d1=0.383, d2=0.430 g=2.170
# >493, 6/8, d1=0.551, d2=0.302 g=1.901
# >493, 7/8, d1=0.359, d2=0.030 g=1.120
# >493, 8/8, d1=0.406, d2=0.573 g=1.581
# >494, 1/8, d1=0.242, d2=0.684 g=2.242
# >494, 2/8, d1=0.347, d2=0.047 g=2.400
# >494, 3/8, d1=0.381, d2=0.259 g=1.855
# >494, 4/8, d1=0.173, d2=0.130 g=1.444
# >494, 5/8, d1=0.213, d2=0.517 g=1.925
# >494, 6/8, d1=0.212, d2=0.458 g=3.256
# >494, 7/8, d1=0.906, d2=0.167 g=2.756
# >494, 8/8, d1=0.370, d2=0.238 g=1.986
# >495, 1/8, d1=0.078, d2=0.383 g=2.739
# >495, 2/8, d1=1.410, d2=0.225 g=1.669
# >495, 3/8, d1=0.358, d2=0.738 g=2.100
# >495, 4/8, d1=0.138, d2=0.337 g=3.340
# >495, 5/8, d1=0.938, d2=0.331 g=2.276
# >495, 6/8, d1=0.101, d2=0.176 g=2.169
# >495, 7/8, d1=0.598, d2=0.557 g=1.958
# >495, 8/8, d1=0.083, d2=0.116 g=2.209
# >496, 1/8, d1=0.718, d2=0.430 g=2.279
# >496, 2/8, d1=0.044, d2=0.138 g=2.994
# >496, 3/8, d1=0.287, d2=0.114 g=2.964
# >496, 4/8, d1=0.763, d2=0.298 g=1.664
# >496, 5/8, d1=0.190, d2=0.188 g=1.869
# >496, 6/8, d1=0.330, d2=0.353 g=2.062
# >496, 7/8, d1=0.084, d2=0.034 g=1.706
# >496, 8/8, d1=0.369, d2=0.369 g=2.421
# >497, 1/8, d1=0.248, d2=0.239 g=2.463
# >497, 2/8, d1=0.044, d2=0.080 g=2.676
# >497, 3/8, d1=0.025, d2=0.186 g=3.116
# >497, 4/8, d1=0.467, d2=0.235 g=2.754
# >497, 5/8, d1=1.903, d2=0.386 g=2.073
# >497, 6/8, d1=0.221, d2=0.179 g=2.465
# >497, 7/8, d1=0.081, d2=0.162 g=2.116
# >497, 8/8, d1=0.054, d2=0.150 g=2.362
# >498, 1/8, d1=0.155, d2=0.232 g=3.120
# >498, 2/8, d1=0.269, d2=0.357 g=3.121
# >498, 3/8, d1=0.349, d2=0.217 g=2.936
# >498, 4/8, d1=0.127, d2=0.215 g=2.236
# >498, 5/8, d1=0.202, d2=0.299 g=2.293
# >498, 6/8, d1=0.282, d2=0.054 g=2.181
# >498, 7/8, d1=0.136, d2=0.699 g=2.643
# >498, 8/8, d1=0.375, d2=0.243 g=2.256
# >499, 1/8, d1=0.258, d2=0.189 g=2.264
# >499, 2/8, d1=0.259, d2=0.098 g=2.849
# >499, 3/8, d1=0.209, d2=0.293 g=2.346
# >499, 4/8, d1=0.598, d2=0.162 g=2.520
# >499, 5/8, d1=0.147, d2=0.303 g=2.311
# >499, 6/8, d1=0.182, d2=0.244 g=2.355
# >499, 7/8, d1=0.963, d2=0.169 g=1.781
# >499, 8/8, d1=0.055, d2=0.966 g=3.053
# >500, 1/8, d1=0.249, d2=0.064 g=3.692
# >500, 2/8, d1=0.476, d2=0.193 g=2.972
# >500, 3/8, d1=0.134, d2=0.220 g=2.479
# >500, 4/8, d1=0.337, d2=0.274 g=2.379
# >500, 5/8, d1=0.147, d2=0.115 g=2.077
# >500, 6/8, d1=0.061, d2=0.097 g=2.239
# >500, 7/8, d1=0.220, d2=0.210 g=1.819
# >500, 8/8, d1=0.616, d2=0.341 g=1.734
# 132/132 [==============================] - 0s 1ms/step
# 132/132 [==============================] - 0s 855us/step
# >Accuracy real: 0%, fake: 100%

# %%
from keras.models import load_model

model = load_model('generator_model_500.h5')
vector = np.asarray([[1.0 for _ in range(4096)]])

x= model.predict(vector)
x = (x+1)/2
print("Generated Image")
pyplot.imshow(x[0,:,:,0])
pyplot.show
# Out:
# Generated Image
# <function matplotlib.pyplot.show>
